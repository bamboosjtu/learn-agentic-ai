# %%
import os
from openai import OpenAI
import rich

# %% [markdown]
# Note: we need to use models that support reasoning like o1 and o3-mini

# %%
API_KEY = os.environ.get('OPENAI_API_KEY')
BASE_URL = os.environ.get('OPENAI_BASE_URL')
MODEL = "gpt-5.4"

openai = OpenAI(api_key=API_KEY, base_url=BASE_URL)

# %% [markdown]
# **Advanced reasoning and problem-solving models**

# %% [markdown]
# # Chat Completion API
#
# https://platform.openai.com/docs/guides/reasoning?api-mode=chat

# %% [markdown]
# Reasoning model takes time to respond.

# %%
prompt = """
Write a bash script that takes a matrix represented as a string with
format '[1,2],[3,4],[5,6]' and prints the transpose in the same format.
"""

response = openai.chat.completions.create(
    model=MODEL,
    reasoning_effort="medium",
    messages=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)

print(rich.print(response.usage))
print(response.choices[0].message.content)
# Out:
# CompletionUsage(
#     completion_tokens=643,
#     prompt_tokens=55,
#     total_tokens=698,
#     completion_tokens_details=None,
#     prompt_tokens_details=None
# )
# None
# ```bash
# #!/usr/bin/env bash
#
# # Usage:
# #   ./transpose.sh '[1,2],[3,4],[5,6]'
#
# input="$1"
#
# if [[ -z "$input" ]]; then
#   echo "Usage: $0 '[1,2],[3,4],[5,6]'" >&2
#   exit 1
# fi
#
# # Split rows by replacing "],[" with newlines
# rows_text="${input//],[/\$'\n'}"
# rows_text="${rows_text//],[/$'\n'}"
#
# declare -a rows
# while IFS= read -r line; do
#   # Remove leading/trailing brackets
#   line="${line#[}"
#   line="${line%]}"
#   rows+=("$line")
# done <<< "$rows_text"
#
# row_count=${#rows[@]}
# col_count=0
#
# declare -A matrix
#
# # Parse rows into matrix[row,col]
# for ((i=0; i<row_count; i++)); do
#   IFS=',' read -r -a vals <<< "${rows[i]}"
#
#   if (( i == 0 )); then
#     col_count=${#vals[@]}
#   elif (( ${#vals[@]} != col_count )); then
#     echo "Error: irregular matrix" >&2
#     exit 1
#   fi
#
#   for ((j=0; j<col_count; j++)); do
#     matrix[$i,$j]="${vals[j]}"
#   done
# done
#
# # Print transpose
# out=""
# for ((j=0; j<col_count; j++)); do
#   row="["
#   for ((i=0; i<row_count; i++)); do
#     row+="${matrix[$i,$j]}"
#     (( i < row_count - 1 )) && row+=","
#   done
#   row+="]"
#   out+="$row"
#   (( j < col_count - 1 )) && out+=","
# done
#
# echo "$out"
# ```
#
# Example:
#
# ```bash
# $ ./transpose.sh '[1,2],[3,4],[5,6]'
# [1,3,5],[2,4,6]
# ```
#
# If you want, I can also give you a shorter version using `awk`.

# %%
rich.print(response)
# Out:
# ChatCompletion(
#     id='resp_0c8f1dcbb6a4467d0169d9e72548888191815fbcf3ad1b89ae',
#     choices=[
#         Choice(
#             finish_reason='stop',
#             index=0,
#             logprobs=None,
#             message=ChatCompletionMessage(
#                 content='```bash\n#!/usr/bin/env bash\n\n# Usage:\n#   ./transpose.sh
# \'[1,2],[3,4],[5,6]\'\n\ninput="$1"\n\nif [[ -z "$input" ]]; then\n  echo "Usage: $0 \'[1,2],[3,4],[5,6]\'" >&2\n
# exit 1\nfi\n\n# Split rows by replacing "],[" with
# newlines\nrows_text="${input//],[/\\$\'\\n\'}"\nrows_text="${rows_text//],[/$\'\\n\'}"\n\ndeclare -a rows\nwhile
# IFS= read -r line; do\n  # Remove leading/trailing brackets\n  line="${line#[}"\n  line="${line%]}"\n
# rows+=("$line")\ndone <<< "$rows_text"\n\nrow_count=${#rows[@]}\ncol_count=0\n\ndeclare -A matrix\n\n# Parse rows
# into matrix[row,col]\nfor ((i=0; i<row_count; i++)); do\n  IFS=\',\' read -r -a vals <<< "${rows[i]}"\n\n  if (( i
# == 0 )); then\n    col_count=${#vals[@]}\n  elif (( ${#vals[@]} != col_count )); then\n    echo "Error: irregular
# matrix" >&2\n    exit 1\n  fi\n\n  for ((j=0; j<col_count; j++)); do\n    matrix[$i,$j]="${vals[j]}"\n
# done\ndone\n\n# Print transpose\nout=""\nfor ((j=0; j<col_count; j++)); do\n  row="["\n  for ((i=0; i<row_count;
# i++)); do\n    row+="${matrix[$i,$j]}"\n    (( i < row_count - 1 )) && row+=","\n  done\n  row+="]"\n
# out+="$row"\n  (( j < col_count - 1 )) && out+=","\ndone\n\necho "$out"\n```\n\nExample:\n\n```bash\n$
# ./transpose.sh \'[1,2],[3,4],[5,6]\'\n[1,3,5],[2,4,6]\n```\n\nIf you want, I can also give you a shorter version
# using `awk`.',
#                 refusal=None,
#                 role='assistant',
#                 annotations=None,
#                 audio=None,
#                 function_call=None,
#                 tool_calls=None,
#                 reasoning_content='**Crafting a bash script**\n\nI\'m looking to create a bash script and I need it
# to handle spaces properly. I think it\'s simple to craft a robust script using parameter expansion, specifically
# splitting on "],[", to parse rows into arrays and output a transposed version. While I could use awk, since the
# request is for pure bash, I’ll make sure we take the argument \\$1 to format the input correctly. The tricky part
# will be stripping brackets while splitting by commas. Let\'s see how this works out!'
#             )
#         )
#     ],
#     created=1775888197,
#     model='gpt-5.4',
#     object='chat.completion',
#     service_tier=None,
#     system_fingerprint=None,
#     usage=CompletionUsage(
#         completion_tokens=643,
#         prompt_tokens=55,
#         total_tokens=698,
#         completion_tokens_details=None,
#         prompt_tokens_details=None
#     )
# )

# %% [markdown]
# # Responses API
#
# https://platform.openai.com/docs/guides/reasoning?api-mode=responses

# %%
API_KEY = os.environ.get('AIHUBMIX_API_KEY')
BASE_URL = os.environ.get('AIHUBMIX_BASE_URL')
MODEL = "gpt-5-nano"

openai = OpenAI(api_key=API_KEY, base_url=BASE_URL)

# %%
prompt = """
Write a bash script that takes a matrix represented as a string with
format '[1,2],[3,4],[5,6]' and prints the transpose in the same format.
"""

response = openai.responses.create(
    model=MODEL,
    reasoning={"effort": "medium"}, # reasoning_effort now become reasoning and accept a dictionary
    input=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)

rich.print(response.usage)
print(response.output_text)
# Out:
# ResponseUsage(
#     input_tokens=44,
#     input_tokens_details=InputTokensDetails(cached_tokens=0),
#     output_tokens=4327,
#     output_tokens_details=OutputTokensDetails(reasoning_tokens=3840),
#     total_tokens=4371
# )
# Here's a self-contained Bash script that reads a matrix in the format like "[1,2],[3,4],[5,6]" (3x2) and prints its transpose in the same format "[1,3,5],[2,4,6]".
#
# Save as transpose_matrix.sh and run, e.g.:
# ./transpose_matrix.sh "[1,2],[3,4],[5,6]"
#
# Code:
#
# #!/usr/bin/env bash
# set -euo pipefail
#
# # Get input: as argument or from stdin
# input="${1:-}"
# if [[ -z "$input" ]]; then
#   input="$(cat)"
# fi
#
# # Normalize: remove spaces, split into lines by converting "],["
# lines=$(printf "%s" "$input" | tr -d ' ' | sed 's/\],\[/\n/g' | sed 's/[\[\]]//g')
# mapfile -t rows <<< "$lines"
#
# R=${#rows[@]}
# if (( R == 0 )); then
#   echo ""
#   exit 0
# fi
#
# # Determine number of columns from the first row
# IFS=',' read -r -a first <<< "${rows[0]}"
# C=${#first[@]}
#
# # Build the transpose: trows[j] will be the j-th row of the transpose
# declare -a trows
# for ((j=0; j<C; j++)); do
#   trows[$j]=""
# done
#
# for ((i=0; i<R; i++)); do
#   IFS=',' read -r -a arr <<< "${rows[i]}"
#   for ((j=0; j<C; j++)); do
#     val="${arr[j]}"
#     if [[ -z "${trows[$j]}" ]]; then
#       trows[$j]="$val"
#     else
#       trows[$j]="${trows[$j]},$val"
#     fi
#   done
# done
#
# # Print in the same bracketed format
# out=""
# for ((k=0; k<C; k++)); do
#   if [[ -n "$out" ]]; then
#     out="$out,"
#   fi
#   out="$out[${trows[$k]}]"
# done
#
# echo "$out"
