# %%
import os
from openai import OpenAI
import rich

# %% [markdown]
# Note: we need to use models that support reasoning like o1 and o3-mini

# %%
API_KEY = os.environ.get('AIHUBMIX_API_KEY')
BASE_URL = os.environ.get('AIHUBMIX_BASE_URL')
MODEL = "o3-mini"

openai = OpenAI(api_key=API_KEY, base_url=BASE_URL)

# %% [markdown]
# **Advanced reasoning and problem-solving models**

# %% [markdown]
# # Chat Completion API
#
# https://platform.openai.com/docs/guides/reasoning?api-mode=chat

# %% [markdown]
# Reasoning model takes time to respond.

# %%
prompt = """
Write a bash script that takes a matrix represented as a string with
format '[1,2],[3,4],[5,6]' and prints the transpose in the same format.
"""

response = openai.chat.completions.create(
    model=MODEL,
    reasoning_effort="medium",
    messages=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)

print(rich.print(response.usage))
print(response.choices[0].message.content)
# Out:
# CompletionUsage(
#     completion_tokens=2041,
#     prompt_tokens=44,
#     total_tokens=2085,
#     completion_tokens_details=CompletionTokensDetails(
#         accepted_prediction_tokens=0,
#         audio_tokens=0,
#         reasoning_tokens=1152,
#         rejected_prediction_tokens=0
#     ),
#     prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)
# )
# None
# Below is one solution in Bash. Save the code in (for example) transpose.sh, make it executable (chmod +x transpose.sh), and run it with your matrix string as the first argument. For example:
#
#   ./transpose.sh '[1,2],[3,4],[5,6]'
#
# Here is the full script:
#
# ------------------------------------------------
# #!/bin/bash
# #
# # This script accepts a single argument representing a matrix
# # in the form "[1,2],[3,4],[5,6]" (each row is bracketed and
# # rows are comma‐separated). It computes and prints the transpose
# # in the same format.
# #
#
# # Check for an argument.
# if [ "$#" -ne 1 ]; then
#     echo "Usage: $0 '[row1],[row2],...[rowN]'"
#     exit 1
# fi
#
# input="$1"
#
# # Remove the very first '[' and the very last ']' so that we have:
# # 1,2],[3,4],[5,6
# trimmed="${input#[}"
# trimmed="${trimmed%]}"
#
# # Replace "],[" with a space so we can split into rows.
# rows_str=(${trimmed//],[/ })
#
# # The array "rows_str" now holds each row as a string.
# n_rows=${#rows_str[@]}
# if [ $n_rows -eq 0 ]; then
#     echo "Matrix not recognized."
#     exit 1
# fi
#
# # We'll store the matrix elements in an associative array indexed by "i,j"
# declare -A matrix
#
# # Process every row.
# n_cols=0
# for i in "${!rows_str[@]}"; do
#     # Now replace any remaining commas with a space .
#     # For example "1,2" will become "1 2"
#     row="${rows_str[$i]}"
#     # Remove any stray brackets (if any still remain)
#     row="${row//[/}"
#     row="${row//]/}"
#     # Convert row to an array of its elements.
#     IFS=',' read -ra elems <<< "$row"
#     # Save the number of columns based on the first row.
#     if [ $i -eq 0 ]; then
#         n_cols=${#elems[@]}
#     fi
#     for j in "${!elems[@]}"; do
#         # Trim any extra spaces.
#         elem=$(echo "${elems[$j]}" | xargs)
#         matrix["$i,$j"]=$elem
#     done
# done
#
# # Now compute the transpose.
# # The transpose will have n_cols rows and n_rows columns.
# output=""
#
# for col in $(seq 0 $((n_cols-1))); do
#     # Start the row string with the opening bracket.
#     row_out="["
#     for row in $(seq 0 $((n_rows-1))); do
#         # Get the element from original matrix.
#         row_out+="${matrix["$((row)),$((col))"]}"
#         # Append a comma if not the last element.
#         if [ $row -lt $((n_rows-1)) ]; then
#             row_out+=","
#         fi
#     done
#     row_out+="]"
#     # Append to output string.
#     output+="$row_out"
#     # Append a comma if not the last transposed row.
#     if [ $col -lt $((n_cols-1)) ]; then
#         output+=","
#     fi
# done
#
# # Print the resulting transposed matrix.
# echo "$output"
#
# ------------------------------------------------
#
# How the script works:
#
# 1. It removes the very first "[" and last "]" from the input string.
# 2. It splits the remaining text into rows by replacing the delimiter "],[" with a space.
# 3. For each row, it splits the numbers by commas and fills an associative array indexed by "row,col".
# 4. It then loops over the “columns” of the original matrix, building each new row of the transposed matrix.
# 5. Finally, it prints the transposed matrix in the same "[...],[...]" format.
#
# For the provided example, running:
#
#   ./transpose.sh '[1,2],[3,4],[5,6]'
#
# will output:
#
#   [1,3,5],[2,4,6]

# %%
rich.print(response)
# Out:
# ChatCompletion(
#     id='chatcmpl-DFFjIBfodNbFtWjsmBg273w9bC0p8',
#     choices=[
#         Choice(
#             finish_reason='stop',
#             index=0,
#             logprobs=None,
#             message=ChatCompletionMessage(
#                 content='Below is one solution in Bash. Save the code in (for example) transpose.sh, make it
# executable (chmod +x transpose.sh), and run it with your matrix string as the first argument. For
# example:\n\n\u2003\u2003./transpose.sh \'[1,2],[3,4],[5,6]\'\n\nHere is the full
# script:\n\n------------------------------------------------\n#!/bin/bash\n#\n# This script accepts a single
# argument representing a matrix\n# in the form "[1,2],[3,4],[5,6]" (each row is bracketed and\n# rows are
# comma‐separated). It computes and prints the transpose\n# in the same format.\n#\n\n# Check for an argument.\nif [
# "$#" -ne 1 ]; then\n    echo "Usage: $0 \'[row1],[row2],...[rowN]\'"\n    exit 1\nfi\n\ninput="$1"\n\n# Remove the
# very first \'[\' and the very last \']\' so that we have:\n#
# 1,2],[3,4],[5,6\ntrimmed="${input#[}"\ntrimmed="${trimmed%]}"\n\n# Replace "],[" with a space so we can split into
# rows.\nrows_str=(${trimmed//],[/ })\n\n# The array "rows_str" now holds each row as a
# string.\nn_rows=${#rows_str[@]}\nif [ $n_rows -eq 0 ]; then\n    echo "Matrix not recognized."\n    exit 1\nfi\n\n#
# We\'ll store the matrix elements in an associative array indexed by "i,j"\ndeclare -A matrix\n\n# Process every
# row.\nn_cols=0\nfor i in "${!rows_str[@]}"; do\n    # Now replace any remaining commas with a space .\n    # For
# example "1,2" will become "1 2"\n    row="${rows_str[$i]}"\n    # Remove any stray brackets (if any still remain)\n
# row="${row//[/}"\n    row="${row//]/}"\n    # Convert row to an array of its elements.\n    IFS=\',\' read -ra
# elems <<< "$row"\n    # Save the number of columns based on the first row.\n    if [ $i -eq 0 ]; then\n
# n_cols=${#elems[@]}\n    fi\n    for j in "${!elems[@]}"; do\n        # Trim any extra spaces.\n        elem=$(echo
# "${elems[$j]}" | xargs)\n        matrix["$i,$j"]=$elem\n    done\ndone\n\n# Now compute the transpose.\n# The
# transpose will have n_cols rows and n_rows columns.\noutput=""\n\nfor col in $(seq 0 $((n_cols-1))); do\n    #
# Start the row string with the opening bracket.\n    row_out="["\n    for row in $(seq 0 $((n_rows-1))); do\n
# # Get the element from original matrix.\n        row_out+="${matrix["$((row)),$((col))"]}"\n        # Append a
# comma if not the last element.\n        if [ $row -lt $((n_rows-1)) ]; then\n            row_out+=","\n        fi\n
# done\n    row_out+="]"\n    # Append to output string.\n    output+="$row_out"\n    # Append a comma if not the
# last transposed row.\n    if [ $col -lt $((n_cols-1)) ]; then\n        output+=","\n    fi\ndone\n\n# Print the
# resulting transposed matrix.\necho "$output"\n\n------------------------------------------------\n\nHow the script
# works:\n\n1. It removes the very first "[" and last "]" from the input string.\n2. It splits the remaining text
# into rows by replacing the delimiter "],[" with a space.\n3. For each row, it splits the numbers by commas and
# fills an associative array indexed by "row,col".\n4. It then loops over the “columns” of the original matrix,
# building each new row of the transposed matrix.\n5. Finally, it prints the transposed matrix in the same
# "[...],[...]" format.\n\nFor the provided example, running:\n\n\u2003\u2003./transpose.sh
# \'[1,2],[3,4],[5,6]\'\n\nwill output:\n\n\u2003\u2003[1,3,5],[2,4,6]',
#                 refusal=None,
#                 role='assistant',
#                 annotations=None,
#                 audio=None,
#                 function_call=None,
#                 tool_calls=None
#             )
#         )
#     ],
#     created=1772527756,
#     model='o3-mini-2025-01-31',
#     object='chat.completion',
#     service_tier=None,
#     system_fingerprint='fp_0d2bf52fac',
#     usage=CompletionUsage(
#         completion_tokens=2041,
#         prompt_tokens=44,
#         total_tokens=2085,
#         completion_tokens_details=CompletionTokensDetails(
#             accepted_prediction_tokens=0,
#             audio_tokens=0,
#             reasoning_tokens=1152,
#             rejected_prediction_tokens=0
#         ),
#         prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)
#     )
# )

# %% [markdown]
# # Responses API
#
# https://platform.openai.com/docs/guides/reasoning?api-mode=responses

# %%
prompt = """
Write a bash script that takes a matrix represented as a string with
format '[1,2],[3,4],[5,6]' and prints the transpose in the same format.
"""

response = openai.responses.create(
    model=MODEL,
    reasoning={"effort": "medium"}, # reasoning_effort now become reasoning and accept a dictionary
    input=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)

rich.print(response.usage)
print(response.output_text)
# Out:
# ResponseUsage(
#     input_tokens=44,
#     input_tokens_details=InputTokensDetails(cached_tokens=0),
#     output_tokens=1868,
#     output_tokens_details=OutputTokensDetails(reasoning_tokens=1024),
#     total_tokens=1912
# )
# Below is one example of a Bash script that accepts a matrix string in the format
#   [1,2],[3,4],[5,6]
# and prints its transpose in the same format. Save the following code (for example as transpose.sh), give it execute permissions (chmod +x transpose.sh), and run it.
#
# Below is the annotated script:
#
# ------------------------------------------------
# #!/bin/bash
# # Check that we received exactly one argument.
# if [ "$#" -ne 1 ]; then
#   echo "Usage: $0 '<matrix>'"
#   exit 1
# fi
#
# # Read the input string.
# matrix_str="$1"
#
# # Remove any spaces (if any).
# matrix_str=$(echo "$matrix_str" | tr -d ' ')
#
# # Convert the input string into individual rows.
# # Replace "],[" with a newline and remove the initial "[" and trailing "]"
# rows_str=$(echo "$matrix_str" | sed -e 's/\],\[/\n/g' -e 's/^\[//' -e 's/\]$//')
#
# # Read rows into an array.
# rows=()
# while IFS= read -r line; do
#   rows+=( "$line" )
# done <<< "$rows_str"
#
# num_rows=${#rows[@]}
# if [ "$num_rows" -eq 0 ]; then
#   echo "Empty matrix"
#   exit 1
# fi
#
# # Determine the number of columns by splitting the first row at commas.
# IFS=',' read -r -a first_row_array <<< "${rows[0]}"
# num_cols=${#first_row_array[@]}
#
# # We'll use an associative array to store the transposed matrix.
# # The key "i,j" will represent the element in row i and column j of the transposed matrix.
# declare -A tmat
#
# # Iterate over the input rows.
# for (( i=0; i<num_rows; i++ )); do
#   # Split the i-th row into its elements.
#   IFS=',' read -r -a row_array <<< "${rows[i]}"
#   # Check that every row has the same number of columns.
#   if [ "${#row_array[@]}" -ne "$num_cols" ]; then
#     echo "Inconsistent number of columns in row $((i+1))"
#     exit 1
#   fi
#   # For the transpose, assign element (j,i) of the output = (i,j) of the input.
#   for (( j=0; j<num_cols; j++ )); do
#     tmat["$j,$i"]="${row_array[j]}"
#   done
# done
#
# # Now build the output string in the same format.
# output=""
# for (( i=0; i<num_cols; i++ )); do
#   row_str="["
#   for (( j=0; j<num_rows; j++ )); do
#     row_str+="${tmat[$i,$j]}"
#     if [ $j -lt $((num_rows-1)) ]; then
#       row_str+=","
#     fi
#   done
#   row_str+="]"
#   if [ $i -lt $((num_cols-1)) ]; then
#     output+="${row_str},"
#   else
#     output+="${row_str}"
#   fi
# done
#
# # Print the transposed matrix.
# echo "$output"
#
# ------------------------------------------------
#
# Explanation:
# 1. The script first makes sure it has exactly one argument.
# 2. It removes spaces, then uses sed to split the comma-separated rows into newlines while removing the outer square brackets.
# 3. It then splits each row into an array of numbers, ensuring each row has the same number of columns.
# 4. The nested loops store the transposed values in an associative array.
# 5. Finally, it constructs and prints the output string formatted as: [a1,a2,...],[b1,b2,...], etc.
#
# Example:
#   $ ./transpose.sh '[1,2],[3,4],[5,6]'
# outputs:
#   [1,3,5],[2,4,6]
#
# This solution works for numeric (or similar) entries in the matrix.
