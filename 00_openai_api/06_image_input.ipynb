# %%
import os
from openai import OpenAI
import rich

# %%
API_KEY = os.environ.get('OPENROUTER_API_KEY')
BASE_URL = os.environ.get('OPENROUTER_BASE_URL')
MODEL = "gpt-5.4"

openai = OpenAI(api_key=API_KEY, base_url=BASE_URL)

# %% [markdown]
# **Sending images as input prompt and generating response based on the data inside thoese images**

# %% [markdown]
# # Chat Completion API
#
# https://platform.openai.com/docs/guides/images?api-mode=chat

# %%
response = openai.chat.completions.create(
    model=MODEL,
    messages= [
        { "role": "user", "content": [
            {"type": "text", "text": "这张图片展示了什么内容?"},
            {
                "type": "image_url",
                "image_url": {
                    "url": "https://mma.prnasia.com/media2/1628387/1.jpg",
                },
            },
        ]}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# 这是一幅卡通风格的森林场景插画。
#
# 画面中：
# - 左边是一只粉色的小狐狸，头上戴着一朵紫色花。
# - 它正拿着放大镜，像是在观察一只蓝色的蝴蝶。
# - 右边站着一只棕色的小熊，看起来在开心地看着小狐狸和蝴蝶。
# - 周围是树木、草丛和花朵，整体氛围很轻松可爱。
#
# 如果你愿意，我也可以帮你把这张图描述得更适合“给小朋友讲故事”或“用于看图说话”。

# %% [markdown]
# ### Base64 encoded image

# %%
image_path = "linabell with friends.jpg"

# %%
import base64
# Function to encode the image
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")


# If you run this example on your local machine then you just need provide image file path
# Path to your image
# image_path = "./car.jpg"

# Getting the Base64 string
base64_image = encode_image(image_path)

completion = openai.chat.completions.create(
    model=MODEL,
    messages=[
        {
            "role": "user",
            "content": [
                { "type": "text", "text": "这张图片展示了什么内容?" },
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{base64_image}",
                    },
                },
            ],
        }
    ],
)

print(completion.choices[0].message.content)
# Out:
# 这张图片展示的是一群可爱的毛绒卡通动物玩偶，在草地上像是在跳舞或摆出欢乐的姿势。
#
# 画面中可以看到：
# - 一只粉紫色的兔子
# - 一只棕色小熊
# - 一只粉色狐狸
# - 一只棕色小熊/小狗形象的玩偶
# - 一只绿色猫咪
# - 一只黄色小狗
# - 一只绿色乌龟
#
# 背景是明亮的蓝天、柔和的白云、花草和一只飞舞的蓝色蝴蝶，整体氛围非常梦幻、春天感十足，也很像迪士尼风格的角色合影。
#
# 如果你愿意，我还可以帮你进一步识别这些角色分别是谁。

# %% [markdown]
# # Responses API
#
# https://platform.openai.com/docs/guides/images?api-mode=responses

# %% [markdown]
# Following values of property `type` are changed in Responses API
#
# text -> input_text
#
# image_url -> input_image
#
# ```
# "content": [
#     { "type": "input_text", "text": "what's in this image?" },
#     {
#         "type": "input_image",
#         "image_url": f"data:image/jpeg;base64,{base64_image}",
#     },
# ],
# ```

# %%
response = openai.responses.create(
    model=MODEL,
    input=[{
        "role": "user",
        "content": [
            {"type": "input_text", "text": "图片里展现了什么内容?"},
            {
                "type": "input_image",
                "image_url": "https://q6.itc.cn/images01/20240425/cad48d77561f4d76a593185452b110a9.jpeg",
            },
        ],
    }],
)

# %%
print(response.output_text)
# Out:
# 图片展示的是一座城市的天际线，前景是密集的高楼建筑，背景是一大片被白雪覆盖的山脉。
#
# 更具体地看：
# - 画面主体是城市建筑群，包含住宅楼、办公楼和几栋较高的地标式建筑。
# - 中间偏上的位置有一座很显眼的高塔建筑，顶部是圆顶，像钟楼或历史风格的现代建筑。
# - 背后是连绵起伏的高山，山体覆雪，显得天气较冷。
# - 整体给人的感觉像是“山脚下的大城市”，城市与自然山景形成强烈对比。
#
# 如果你愿意，我也可以进一步帮你判断这可能是哪座城市。

# %% [markdown]
# ### Base64 encoded image

# %% [markdown]
# Google Drive is already mounted in above example

# %%
# Function to encode the image
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")


# Path to your image
# image_path = "./car.jpg"

# Getting the Base64 string
base64_image = encode_image(image_path)


response = openai.responses.create(
    model=MODEL,
    input=[
        {
            "role": "user",
            "content": [
                { "type": "input_text", "text": "这张图片的内容是那个IP，主角是谁?" },
                {
                    "type": "input_image",
                    "image_url": f"data:image/jpeg;base64,{base64_image}",
                },
            ],
        }
    ],
)

print(response.output_text)
# Out:
# 这张图看起来是 **迪士尼“达菲和朋友们”（Duffy and Friends）** 这个 IP。
#
# 图里能认出的角色有：
# - **达菲熊（Duffy）**：中间偏右的棕色小熊
# - **雪莉玫（ShellieMay）**：左侧棕粉色小熊
# - **星黛露（StellaLou）**：最左边紫色兔子
# - **玲娜贝儿（LinaBell）**：中间偏左粉色小狐狸
# - **杰拉多尼（Gelatoni）**：后排偏右绿色小猫
# - **可琦安（CookieAnn）**：右侧黄色小狗
# - **奥乐米拉（‘Olu Mel）**：最右边绿色小海龟
#
# 如果问这个 IP 的“主角是谁”，通常公认的核心主角是 **达菲熊（Duffy）**，因为“达菲和朋友们”就是以达菲为中心发展出来的角色系列。
#
# 如果你愿意，我也可以继续帮你把图中每个角色的位置一一标出来。
