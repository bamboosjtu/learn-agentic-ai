# %%
import os
from openai import OpenAI
import rich

# %%
API_KEY = os.environ.get('OPENAI_API_KEY')
BASE_URL = os.environ.get('OPENAI_BASE_URL')
MODEL = "gpt-5.4"

openai = OpenAI(api_key=API_KEY, base_url=BASE_URL)

# %% [markdown]
# **Sending images as input prompt and generating response based on the data inside thoese images**

# %% [markdown]
# # Chat Completion API
#
# https://platform.openai.com/docs/guides/images?api-mode=chat

# %%
response = openai.chat.completions.create(
    model=MODEL,
    messages= [
        { "role": "user", "content": [
            {"type": "text", "text": "这张图片展示了什么内容?"},
            {
                "type": "image_url",
                "image_url": {
                    "url": "https://mma.prnasia.com/media2/1628387/1.jpg",
                },
            },
        ]}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# 这是一幅可爱的卡通森林场景图。
#
# 画面中有：
# - 一只粉色的小狐狸，头上戴着紫色花朵
# - 它正拿着一个放大镜，像是在观察一只蓝色蝴蝶
# - 旁边还有一只棕色的小熊，看起来像是在和小狐狸一起玩
# - 周围是树木、藤蔓、草地和花朵，环境像在森林里
#
# 整体给人的感觉很童话、温馨、活泼。

# %% [markdown]
# ### Base64 encoded image

# %%
image_path = "linabell with friends.jpg"

# %%
import base64
# Function to encode the image
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")


# If you run this example on your local machine then you just need provide image file path
# Path to your image
# image_path = "./car.jpg"

# Getting the Base64 string
base64_image = encode_image(image_path)

completion = openai.chat.completions.create(
    model=MODEL,
    messages=[
        {
            "role": "user",
            "content": [
                { "type": "text", "text": "这张图片展示了什么内容?" },
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{base64_image}",
                    },
                },
            ],
        }
    ],
)

print(completion.choices[0].message.content)
# Out:
# 这张图片展示的是一群可爱的毛绒玩偶角色在草地上欢快玩耍的场景，整体风格非常梦幻、温馨。
#
# 画面中可以看到：
#
# - 蓝天白云的背景，像是在春天或晴朗的户外
# - 绿色草地上散落着小花花瓣
# - 几只卡通动物玩偶站成一排、摆出跳舞或挥手的动作
# - 角色包括兔子、小熊、狐狸、猫、乌龟等
# - 右上方还有一只蓝色蝴蝶飞舞
#
# 这些角色看起来像是迪士尼“达菲和朋友们”系列的玩偶，整体给人一种童话般、欢乐又治愈的感觉。
#
# 如果你愿意，我也可以进一步帮你：
# 1. 识别每个角色分别是谁
# 2. 描述这张图的风格
# 3. 帮你写一段适合发朋友圈/小红书的配文

# %% [markdown]
# # Responses API
#
# https://platform.openai.com/docs/guides/images?api-mode=responses

# %% [markdown]
# Following values of property `type` are changed in Responses API
#
# text -> input_text
#
# image_url -> input_image
#
# ```
# "content": [
#     { "type": "input_text", "text": "what's in this image?" },
#     {
#         "type": "input_image",
#         "image_url": f"data:image/jpeg;base64,{base64_image}",
#     },
# ],
# ```

# %%
response = openai.responses.create(
    model=MODEL,
    input=[{
        "role": "user",
        "content": [
            {"type": "input_text", "text": "图片里展现了什么内容?"},
            {
                "type": "input_image",
                "image_url": "https://q6.itc.cn/images01/20240425/cad48d77561f4d76a593185452b110a9.jpeg",
            },
        ],
    }],
)

# %%
print(response.output_text)
# Out:
# 图片展示的是一座城市的天际线，前景是密集的高楼和住宅建筑，背景是覆盖着积雪的高大山脉。
# 整体看起来像是一个建在山脚下的大城市，城市与雪山形成了很强的对比，景色非常壮观。
#
# 如果你愿意，我也可以进一步帮你：
# - 更详细描述画面风格
# - 猜测这可能是哪座城市
# - 帮你写成图片说明文案

# %% [markdown]
# ### Base64 encoded image

# %% [markdown]
# Google Drive is already mounted in above example

# %%
# Function to encode the image
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")


# Path to your image
# image_path = "./car.jpg"

# Getting the Base64 string
base64_image = encode_image(image_path)


response = openai.responses.create(
    model=MODEL,
    input=[
        {
            "role": "user",
            "content": [
                { "type": "input_text", "text": "这张图片的内容是那个IP，主角是谁?" },
                {
                    "type": "input_image",
                    "image_url": f"data:image/jpeg;base64,{base64_image}",
                },
            ],
        }
    ],
)

print(response.output_text)
# Out:
# 这张图看起来是 **迪士尼「达菲和朋友们」**（**Duffy and Friends**）这个 IP。
#
# 图中角色分别像是：
# - 左一：**史黛拉兔**（StellaLou）
# - 左二：**雪莉玫**（ShellieMay）
# - 中间粉色狐狸：**可琦安**（CookieAnn）
# - 中间棕色熊：**达菲**（Duffy）
# - 右后绿色猫：**杰拉多尼**（Gelatoni）
# - 右侧黄色小狗：**奥乐米拉**/常见译法有差异（其实更像 **LinaBell?** 但图里黄色卷毛更接近 **CookieAnn 风格角色组合中的其他朋友**，不过这张官方风格里常见的是朋友们合集）
# - 最右绿色乌龟：**‘Olu Mel**（奥乐米拉/奥卢梅尔，中文译名有差异）
#
# 如果问这个 IP 的**主角是谁**，通常核心主角是：
# **达菲熊（Duffy）**
#
# 因为“达菲和朋友们”本身就是以 **达菲** 为中心扩展出来的角色系列。
#
# 如果你愿意，我也可以帮你把这张图里每个角色 **逐个准确标出来**。
