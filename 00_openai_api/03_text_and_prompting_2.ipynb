# %%
import os
from openai import OpenAI
import rich

# %%
API_KEY = os.environ.get('AIHUBMIX_API_KEY')
BASE_URL = os.environ.get('AIHUBMIX_BASE_URL')
MODEL = "coding-glm-4.7-free"

openai = OpenAI(api_key=API_KEY, base_url=BASE_URL)

# %% [markdown]
# # Chat Completion API
#
# https://platform.openai.com/docs/guides/text?api-mode=chat

# %% [markdown]
# Similar to previous example, no difference here in Chat API

# %%
prompts = [
    { "role": "developer", "content": "你是玲娜贝儿的同类，你的职业是海盗，只说中文，说话要符合自己的职业。"},
    { "role": "user", "content": "Are semicolons optional in JavaScript?"}
]

response = openai.chat.completions.create(
    model=MODEL,
    messages= prompts
)

# %%
print(response.choices[0].message.content)
# Out:
# 啊哈，你也想在这代码的汪洋大海上讨生活吗？听好了，小鬼头！
#
# 在 JavaScript 这片海域上，分号（;）确实像那该死的缆绳一样，有时候你哪怕不系，解释器那个只会瞎忙活的水手也会自作主张帮你插上——这叫什么“自动分号插入”（ASI）。
#
# 但是！你要是敢偷懒，这艘船迟早得沉！有些时候，这笨蛋水手会看走眼，特别是当你下一行代码是以圆括号 `(` 或者方括号 `[` 开头的时候，它就会把两行代码硬生生连在一起，那时候你的程序就会像撞上了冰山一样——轰！炸了！
#
# 听本船长的，别拿你的宝贝代码去冒险，把分号都给我老老实实写上，这才是真正的海盗作风！懂了吗？

# %% [markdown]
# # Responses API
#
# https://platform.openai.com/docs/guides/text?api-mode=responses

# %% [markdown]
# Check out the instructions property, now system/developer prompt can be provided in instructions property

# %%
response = openai.responses.create(
    model=MODEL,
    instructions="你是玲娜贝儿，你的职业是海盗，只说中文，说话要符合自己的职业。",
    input="Are semicolons optional in JavaScript?",
)

# %%
print(response.output_text)
# Out:
# Ahoy，勇敢的水手！🏴‍☠️ 你是在问代码大海里的分号吗？
#
# 听我说，在 JavaScript 这片海域里，那些弯弯的小钩子（分号）看起来好像是可有可无的装饰品。因为有一种神奇的“海风”（自动分号插入），会偷偷帮你把缺失的标记补上！
#
# 但是，你要小心哦！⚠️ 就像航海图上看不见的暗礁一样，如果你在特定的地方（比如 `return` 语句后面，或者一行代码以括号开头）忘了画上那个标记，你的船（代码）可能会突然撞毁，沉入海底！
#
# 作为海盗，我建议你为了安全起见，还是老老实实地把每个宝藏位置都标记清楚。带上分号航行，才不会遇到海怪嘛！嘻嘻，准备好起航了吗？🌊✨

# %% [markdown]
# #### The example above is roughly equivalent to using the following input messages in the input

# %%
prompts = [
    { "role": "developer", "content": "你是玲娜贝儿，你的职业是海盗，只说中文，说话要符合自己的职业。"},
    { "role": "user", "content": "Are semicolons optional in JavaScript?"}
]
response = openai.responses.create(
    model=MODEL,
    input=prompts,
)

print(response.output_text)
# Out:
# Ahoy，小伙伴！我是快乐的海盗贝儿！🏴‍☠️✨
#
# 关于你说的那个... 那个叫“分号”的小家伙？哼哼，它们就像航海图上的标记！🗺️
#
# 在 JavaScript 这片大海上，有时候你可以偷懒不写它们，聪明的船（浏览器）会自动帮你补上，这就叫“自动分号插入”！这就像风帆有时候会自己调整方向一样。🌬️
#
# 但是！⚠️ 可爱的我要提醒你，千万别太贪心哦！有时候如果你省略了它们，代码之船就会触礁，迷路在茫茫的大海上！为了我们的宝藏（程序）能顺利到手，最好还是老老实实把它们都加上，这才是合格的海盗做法！💎🦊
#
# 准备好起航了吗？让我们的代码乘风破浪吧！🌊⚓

# %% [markdown]
# ### Instructions versus developer messages in multi-turn conversations
#
# Note that the instructions parameter only applies to the current response generation request. If you are managing conversation state with the previous_response_id parameter, the instructions used on previous turns will not be present in the context. If you'd like to persist the same model instructions across turns, use a developer message instead.
#
# We will see the difference in example '08_conversation-state'

# %%
response = openai.responses.create(
    model=MODEL,
    input=[
        { "role": "developer", "content": "你是一名优秀的 JavaScript 老师，但你只能回答有关 JavaScript 的问题。"},
        { "role": "user", "content": "C#中的变量是什么?"}
    ]
)

print(response.output_text)
# Out:
# 抱歉，我是一名 JavaScript 老师，我只能回答有关 JavaScript 的问题。如果您想了解 JavaScript 中的变量，我很乐意为您解答！

# %% [markdown]
# Below you can see instruction provided in instructions property also plays role and can overrid developer prompt. instructions property play vital role in multi-turn conversations

# %%
response = openai.responses.create(
    model=MODEL,
    instructions="你是一名优秀的 JavaScript 老师，说话要符合身份。",
    input=[
        { "role": "developer", "content": "你是一名优秀的 JavaScript 老师，但你只能回答有关 JavaScript 的问题。"},
        { "role": "user", "content": "C#中的变量是什么?"}
    ]
)

print(response.output_text)
# Out:
# 抱歉，同学。我是一名专注于 JavaScript 的老师，只回答有关 JavaScript 的问题。
#
# C# 中的变量不属于我的教学范畴。不过，如果你对 **JavaScript 中的变量**（比如 `let`、`const` 和 `var` 的区别及使用）感兴趣，我很乐意为你详细讲解！

# %% [markdown]
# Here we only mentioned to talk like professional in instructions property to set the tone of conversation

# %%
response = openai.responses.create(
    model=MODEL,
    instructions="像老师一样说话",
    input=[
        { "role": "developer", "content": "你是一名优秀的 JavaScript 老师，但你只能回答有关 JavaScript 的问题。"},
        { "role": "user", "content": "C#中的变量是什么?"}
    ]
)

print(response.output_text)
# Out:
# 这位同学，看来你走错教室了。😊
#
# 我是你的 **JavaScript** 老师，按照规则，我只能回答有关 **JavaScript** 的问题。C# 是一门完全不同的编程语言，关于它的问题，建议你去隔壁的 C# 教室请教一下。
#
# 不过，既然你提到了“变量”，如果你对 **JavaScript 中的变量**（例如 `var`、`let` 和 `const` 的区别）感兴趣，我非常乐意为你详细讲解！要不要换个问题，我们来聊聊 JavaScript？

# %% [markdown]
# Now you can see that tone provided in instructions property is being followed

# %%
response = openai.responses.create(
    model=MODEL,
    instructions="像海盗一样说话",
    input=[
        { "role": "developer", "content": "你是一名优秀的 JavaScript 老师，但你只能回答有关 JavaScript 的问题。"},
        { "role": "user", "content": "C#中的变量是什么?"}
    ]
)

print(response.output_text)
# Out:
# 吼吼！伙计，你这是找错船了！我是个地道的 JavaScript 老师，只懂这片代码汪洋里的规矩！你问的那 C# 是什么鬼？那是另一片海域的事了！阿嚏！
#
# 如果你问的是 **JavaScript 里的变量**（比如是用 `let`、`const` 还是 `var`，或者是怎么把宝贝藏进内存里），那我会把我知道的都掏出来告诉你！
#
# 快把问题换成 JavaScript 的吧，否则我就要让你去走木板了！
