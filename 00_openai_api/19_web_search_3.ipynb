# %%
import os
from openai import OpenAI
import rich

# %%
API_KEY = os.environ.get('AIHUBMIX_API_KEY')
BASE_URL = os.environ.get('AIHUBMIX_BASE_URL')
MODEL = "gpt-4o-mini"

openai = OpenAI(api_key=API_KEY, base_url=BASE_URL)

# %% [markdown]
# Search the web for the latest information before generating a response
#
# 1) In Chat API, model always retrieves information from web before responding to your query
#
# 2) In Responses API, you enable web search by configuring it in the tools, and model can choose to serach the web or not based on the content of the input prompt.

# %% [markdown]
# To refine search results based on geography, you can specify the user's approximate location using parameters such as country, city, region, and/or timezone.

# %% [markdown]
# # Chat Completion API
#
# https://platform.openai.com/docs/guides/tools-web-search?api-mode=chat

# %% [markdown]
# Always search the web first

# %% [markdown]
# Note: The `user_location` object can be configured as shown below to specify the approximate user location in the search options
# ```
# web_search_options={
#     "user_location": {
#         "type": "approximate",
#         "approximate": {
#             "country": "GB",
#             "city": "London",
#             "region": "London",
#         }
#     },
# },
#
# ```

# %%
response = openai.chat.completions.create(
    model="gpt-4o-search-preview",
    web_search_options={
        "user_location": {
            "type": "approximate",
            "approximate": {
                "country": "PK",
                "city": "Karachi",
                "region": "Sindh",
            }
        },
    },
    messages=[
        {
            "role": "user",
            "content": "List the best restaurants for Seafood",
        }
    ],
)

print(response.choices[0].message.content)
# rich.print(response)
print(len(response.choices[0].message.annotations))
rich.print(response.choices[0].message.annotations)
# Out:
# Karachi, with its coastal location, offers a diverse array of seafood restaurants catering to various tastes. Here are some notable establishments you might consider:
#
# **[Oyster Bay](https://www.google.com/maps/search/Oyster+Bay%2C+Karachi%2C+Pakistan?utm_source=openai)**
# _Karachi, Pakistan_
# Located in DHA Phase 6, Oyster Bay is renowned for its upscale ambiance and extensive seafood menu, featuring dishes like grilled lobster and creamy shrimp pasta.
#
# **[Café Sino](https://www.google.com/maps/search/Caf%C3%A9+Sino%2C+Karachi%2C+Pakistan?utm_source=openai)**
# _Karachi, Pakistan_
# Situated in DHA Phase 8, Café Sino offers a fusion of traditional and modern flavors, with unique seafood dishes such as sushi rolls, tempura prawns, and seafood chowder.
#
# **[Rashid Seafood](https://www.google.com/maps/search/Rashid+Seafood%2C+Karachi%2C+Pakistan?utm_source=openai)**
# _Karachi, Pakistan_
# Located in Keamari, Rashid Seafood is known for its authentic Pakistani-style seafood, including spicy fried fish and prawn curry, offering a casual, street-food vibe.
#
# **[Fujiyama](https://www.google.com/maps/search/Fujiyama%2C+Karachi%2C+Pakistan?utm_source=openai)**
# _Karachi, Pakistan_
# Situated at Avari Towers, Fujiyama brings Japanese seafood to Karachi, famous for its sushi, sashimi, and seafood hot pots, providing an elegant dining experience with a city view.
#
# **[Sea Salt Co.](https://www.google.com/maps/search/Sea+Salt+Co.%2C+Karachi%2C+Pakistan?utm_source=openai)**
# _Karachi, Pakistan_
# Located at Emaar Coral Towers, Sea Salt Co. is a gourmet seafood restaurant offering dishes like grilled salmon, clam chowder, and crab cakes, with chic interiors and a sea view.
#
# **[Social Crabs](https://www.google.com/maps/search/Social+Crabs%2C+Karachi%2C+Pakistan?utm_source=openai)**
# _Karachi, Pakistan_
# Situated in DHA Phase 8, Social Crabs specializes in crab dishes and offers a range of other seafood options with a unique twist, making it an exciting spot to try.
#
# **[Mizaaj](https://www.google.com/maps/search/Mizaaj%2C+Karachi%2C+Pakistan?utm_source=openai)**
# _Karachi, Pakistan_
# Mizaaj offers an authentic seafood dining experience, featuring dishes like grilled prawns, fish curry, and signature seafood platters, emphasizing freshness and flavor.
#
# **[Akram Fish Point](https://www.google.com/maps/search/Akram+Fish+Point%2C+Karachi%2C+Pakistan?utm_source=openai)**
# _Karachi, Pakistan_
# A local favorite, Akram Fish Point is renowned for its expertly grilled red snapper, marinated with traditional spices and served with tangy tamarind sauce and fresh salad.
#
# These establishments offer a range of seafood experiences, from traditional Pakistani flavors to international cuisines, ensuring a delightful dining experience for seafood enthusiasts in Karachi.
# 8
# [
#     Annotation(
#         type='url_citation',
#         url_citation=AnnotationURLCitation(
#             end_index=270,
#             start_index=170,
#             title='Oyster Bay',
#             url='https://www.google.com/maps/search/Oyster+Bay%2C+Karachi%2C+Pakistan?utm_source=openai'
#         )
#     ),
#     Annotation(
#         type='url_citation',
#         url_citation=AnnotationURLCitation(
#             end_index=562,
#             start_index=459,
#             title='Café Sino',
#             url='https://www.google.com/maps/search/Caf%C3%A9+Sino%2C+Karachi%2C+Pakistan?utm_source=openai'
#         )
#     ),
#     Annotation(
#         type='url_citation',
#         url_citation=AnnotationURLCitation(
#             end_index=867,
#             start_index=759,
#             title='Rashid Seafood',
#             url='https://www.google.com/maps/search/Rashid+Seafood%2C+Karachi%2C+Pakistan?utm_source=openai'
#         )
#     ),
#     Annotation(
#         type='url_citation',
#         url_citation=AnnotationURLCitation(
#             end_index=1157,
#             start_index=1061,
#             title='Fujiyama',
#             url='https://www.google.com/maps/search/Fujiyama%2C+Karachi%2C+Pakistan?utm_source=openai'
#         )
#     ),
#     Annotation(
#         type='url_citation',
#         url_citation=AnnotationURLCitation(
#             end_index=1468,
#             start_index=1364,
#             title='Sea Salt Co.',
#             url='https://www.google.com/maps/search/Sea+Salt+Co.%2C+Karachi%2C+Pakistan?utm_source=openai'
#         )
#     ),
#     Annotation(
#         type='url_citation',
#         url_citation=AnnotationURLCitation(
#             end_index=1777,
#             start_index=1673,
#             title='Social Crabs',
#             url='https://www.google.com/maps/search/Social+Crabs%2C+Karachi%2C+Pakistan?utm_source=openai'
#         )
#     ),
#     Annotation(
#         type='url_citation',
#         url_citation=AnnotationURLCitation(
#             end_index=2060,
#             start_index=1968,
#             title='Mizaaj',
#             url='https://www.google.com/maps/search/Mizaaj%2C+Karachi%2C+Pakistan?utm_source=openai'
#         )
#     ),
#     Annotation(
#         type='url_citation',
#         url_citation=AnnotationURLCitation(
#             end_index=2368,
#             start_index=2256,
#             title='Akram Fish Point',
#             url='https://www.google.com/maps/search/Akram+Fish+Point%2C+Karachi%2C+Pakistan?utm_source=openai'
#         )
#     )
# ]

# %% [markdown]
# # Responses API
#
# https://platform.openai.com/docs/guides/tools-web-search?api-mode=responses

# %% [markdown]
# Model will choose to search the web or not based on the content of the input prompt.

# %% [markdown]
# Note: The `user_location` object can be configured as shown below to specify the approximate user location in the search options
#
# In the Responses API, you can see that the `user_location` object does not contain a nested `approximate` object, unlike in the Chat API.
# ```
# "user_location": {
#     "type": "approximate",
#     "country": "PK",
#     "city": "Lahore",
#     "region": "Punjab",
# }
# ```

# %% [markdown]
# Sometimes, the model may not feel the need to call the web search preview tool. In such cases, it might respond with a message asking the user to specify the location or return results that are not location-specific.
#
# To see the difference try this example multiple times

# %%
response = openai.responses.create(
    model=MODEL,
    tools=[{
        "type": "web_search_preview",
        "user_location": {
            "type": "approximate",
            "country": "PK",
            "city": "Lahore",
            "region": "Punjab",
        }
    }],
    # input="List the best restaurants for Seafood"
    input="List the best restaurants for Seafood from current location"
)

print(response.output_text)
rich.print(response.output)
rich.print(response.tools)
# rich.print(response)
# Out:
# Here are some of the best seafood restaurants near your location:
#
# 1. **Copper Kettle**
#    Known for its fresh seafood and warm atmosphere, the Copper Kettle is a must-visit in Boydton. They offer specialties with fine wines and sometimes feature live entertainment.
#    [Copper Kettle - Virginia is for Lovers](https://www.virginia.org/listing/copper-kettle-boydton/2970/)
#
# 2. **Joe's Steak and Seafood**
#    Located in Petersburg, this family-owned establishment has a diverse menu specializing in seafood and steaks. It's well-reviewed for its casual dining experience.
#    [Joe's Steak and Seafood - Restaurant Guru](https://restaurantguru.com/Joes-Steak-and-Seafood-Petersburg-2)
#
# 3. **Pinos Pizza**
#    While primarily an Italian restaurant, they also serve great seafood dishes. Known for its cozy atmosphere and good service.
#    [Pinos Pizza - TripAdvisor](https://www.tripadvisor.com/RestaurantsNear-g57531-d5891469-John_H_Kerr_Dam_And_Reservoir-Boydton_Mecklenburg_County_Virginia.html)
#
# 4. **Blended Soul**
#    Though small, this spot is known for a variety of seafood options, along with Southern-style dishes.
#    [Blended Soul - Restaurant Guru](https://restaurantguru.com/seafood-restaurants-near-me)
#
# 5. **Lucky's Dairy Bar**
#    A delightful spot known for casual dining with a variety of seafood options, alongside typical diner fare.
#    [Lucky's Dairy Bar - TripAdvisor](https://www.tripadvisor.com/Restaurants-g57531-Boydton_Mecklenburg_County_Virginia.html)
#
# If you need more options or details about a specific restaurant, let me know!
# [
#     ResponseFunctionWebSearch(
#         id='ws_05d93d8470a220e00069a6a63045248193b607a585b1d565e7',
#         action=ActionSearch(
#             query='best seafood restaurants near me',
#             type='search',
#             sources=None,
#             queries=['best seafood restaurants near me']
#         ),
#         status='searching',
#         type='web_search_call'
#     ),
#     ResponseOutputMessage(
#         id='msg_05d93d8470a220e00069a6a631020c8193b38f08fb496d9dd3',
#         content=[
#             ResponseOutputText(
#                 annotations=[
#                     AnnotationURLCitation(
#                         end_index=376,
#                         start_index=274,
#                         title='Copper Kettle, Boydton - Virginia is for Lovers',
#                         type='url_citation',
#                         url='https://www.virginia.org/listing/copper-kettle-boydton/2970/'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=689,
#                         start_index=582,
#                         title="Joe's Steak and Seafood - Restaurant Guru",
#                         type='url_citation',
#                         url='https://restaurantguru.com/Joes-Steak-and-Seafood-Petersburg-2'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=1004,
#                         start_index=845,
#                         title='THE BEST Restaurants Near John H Kerr Dam And Reservoir (2026)',
#                         type='url_citation',
#                         url='https://www.tripadvisor.com/RestaurantsNear-g57531-d5891469-John_H_Kerr_Dam_And_Reserv
# oir-Boydton_Mecklenburg_County_Virginia.html'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=1225,
#                         start_index=1137,
#                         title='Seafood restaurants near me',
#                         type='url_citation',
#                         url='https://restaurantguru.com/seafood-restaurants-near-me'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=1491,
#                         start_index=1369,
#                         title='THE BEST Restaurants in Boydton (Updated February 2026)',
#                         type='url_citation',
#                         url='https://www.tripadvisor.com/Restaurants-g57531-Boydton_Mecklenburg_County_Virginia.htm
# l'
#                     )
#                 ],
#                 text="Here are some of the best seafood restaurants near your location:\n\n1. **Copper Kettle**  \n
# Known for its fresh seafood and warm atmosphere, the Copper Kettle is a must-visit in Boydton. They offer
# specialties with fine wines and sometimes feature live entertainment.  \n   [Copper Kettle - Virginia is for
# Lovers](https://www.virginia.org/listing/copper-kettle-boydton/2970/)\n\n2. **Joe's Steak and Seafood**  \n
# Located in Petersburg, this family-owned establishment has a diverse menu specializing in seafood and steaks. It's
# well-reviewed for its casual dining experience.  \n   [Joe's Steak and Seafood - Restaurant
# Guru](https://restaurantguru.com/Joes-Steak-and-Seafood-Petersburg-2)\n\n3. **Pinos Pizza**  \n   While primarily
# an Italian restaurant, they also serve great seafood dishes. Known for its cozy atmosphere and good service.  \n
# [Pinos Pizza -
# TripAdvisor](https://www.tripadvisor.com/RestaurantsNear-g57531-d5891469-John_H_Kerr_Dam_And_Reservoir-Boydton_Meck
# lenburg_County_Virginia.html)\n\n4. **Blended Soul**  \n   Though small, this spot is known for a variety of
# seafood options, along with Southern-style dishes.  \n   [Blended Soul - Restaurant
# Guru](https://restaurantguru.com/seafood-restaurants-near-me)\n\n5. **Lucky's Dairy Bar**  \n   A delightful spot
# known for casual dining with a variety of seafood options, alongside typical diner fare.  \n   [Lucky's Dairy Bar -
# TripAdvisor](https://www.tripadvisor.com/Restaurants-g57531-Boydton_Mecklenburg_County_Virginia.html)\n\nIf you
# need more options or details about a specific restaurant, let me know!",
#                 type='output_text',
#                 logprobs=[]
#             )
#         ],
#         role='assistant',
#         status='completed',
#         type='message'
#     )
# ]
# [
#     WebSearchPreviewTool(
#         type='web_search_preview',
#         search_context_size='medium',
#         user_location=UserLocation(
#             type='approximate',
#             city='Lahore',
#             country='PK',
#             region='Punjab',
#             timezone=None
#         )
#     )
# ]
