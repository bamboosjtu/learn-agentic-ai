# %% [markdown]
# # Install openai-agents SDK

# %%
# !pip install -Uq openai-agents
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.3/129.3 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.4/100.4 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 3.0 MB/s eta 0:00:00

# %% [markdown]
# # Make your Notebook capable of running asynchronous functions.
# Both Jupyter notebooks and Python’s asyncio library utilize event loops, but they serve different purposes and can sometimes interfere with each other.
#
# The nest_asyncio library allows the existing event loop to accept nested event loops, enabling asyncio code to run within environments that already have an event loop, such as Jupyter notebooks.
#
# In summary, both Jupyter notebooks and Python’s asyncio library utilize event loops to manage asynchronous operations. When working within Jupyter notebooks, it’s essential to be aware of the existing event loop to effectively run asyncio code without conflicts.

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# # Config

# %%
from agents import (
    AsyncOpenAI,
    OpenAIChatCompletionsModel
)
import os

# %%
AIHUBMIX_API_KEY = os.environ.get("MODELSCOPE_API_KEY")
MODELSCOPE_BASE_URL = os.environ.get("MODELSCOPE_BASE_URL")


# Check if the API key is present; if not, raise an error
if not gemini_api_key:
    raise ValueError("GEMINI_API_KEY is not set. Please ensure it is defined in your .env file.")

#Reference: https://ai.google.dev/gemini-api/docs/openai
external_client = AsyncOpenAI(
    api_key=MODELSCOPE_API_KEY,
    base_url=MODELSCOPE_BASE_URL,
)

model = OpenAIChatCompletionsModel(
    model="ZhipuAI/GLM-4.7-Flash",
    openai_client=external_client
)

# %%
from agents import set_tracing_disabled
set_tracing_disabled(True)

# %% [markdown]
# # Context Management
#
#
# Context available locally to your code: this is data and dependencies you might need when tool functions run, during callbacks like on_handoff, in lifecycle hooks, etc.
# - You create any Python object you want. A common pattern is to use a dataclass or a Pydantic object.
# - You pass that object to the various run methods (e.g. Runner.run(..., **context=whatever**)).
# - All your tool calls, lifecycle hooks etc will be passed a wrapper object, - RunContextWrapper[T], where T represents your context object type which you can access via wrapper.context.
# - The most important thing to be aware of: every agent, tool function, lifecycle etc for a given agent run must use the same type of context.
#
# You can use the context for things like:
# - Contextual data for your run (e.g. things like a username/uid or other information about the user)
# - Dependencies (e.g. logger objects, data fetchers, etc)
# - Helper functions
#
# [Learning Reference](https://openai.github.io/openai-agents-python/context/)

# %% [markdown]
# # Local Context

# %%
import asyncio
from dataclasses import dataclass

from agents import Agent, RunContextWrapper, Runner, function_tool

@dataclass
class UserInfo1:
    name: str
    uid: int
    location: str = "Pakistan"

@function_tool
async def fetch_user_age(wrapper: RunContextWrapper[UserInfo1]) -> str:
    '''Returns the age of the user.'''
    return f"User {wrapper.context.name} is 30 years old"

@function_tool
async def fetch_user_location(wrapper: RunContextWrapper[UserInfo1]) -> str:
    '''Returns the location of the user.'''
    return f"User {wrapper.context.name} is from {wrapper.context.location}"

async def main():
    user_info = UserInfo1(name="Muhammad Qasim", uid=123)

    agent = Agent[UserInfo1](
        name="Assistant",
        tools=[fetch_user_age,fetch_user_location],
        model=model
    )

    result = await Runner.run(
        starting_agent=agent,
        input="What is the age of the user? current location of his/her?",
        context=user_info,
    )

    print(result.final_output)
    # The user John is 47 years old.

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# Error getting response; filtered.input=[{'content': 'What is the age of the user? current location of his/her?', 'role': 'user'}]
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[14], line 41
#      38     # The user John is 47 years old.
#      40 if __name__ == "__main__":
# ---> 41     asyncio.run(main())
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\tasks.py:306, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     304         result = coro.send(None)
#     305     else:
# --> 306         result = coro.throw(exc)
#     307 except StopIteration as exc:
#     308     if self._must_cancel:
#     309         # Task is cancelled right before coro stops.
#
# Cell In[14], line 31, in main()
#      23 user_info = UserInfo1(name="Muhammad Qasim", uid=123)
#      25 agent = Agent[UserInfo1](
#      26     name="Assistant",
#      27     tools=[fetch_user_age,fetch_user_location],
#      28     model=model
#      29 )
# ---> 31 result = await Runner.run(
#      32     starting_agent=agent,
#      33     input="What is the age of the user? current location of his/her?",
#      34     context=user_info,
#      35 )
#      37 print(result.final_output)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\agents\run.py:223, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, error_handlers, previous_response_id, auto_previous_response_id, conversation_id, session)
#     173 """
#     174 Run a workflow starting at the given agent.
#     175
#    (...)    219     type of the output.
#     220 """
#     222 runner = DEFAULT_AGENT_RUNNER
# --> 223 return await runner.run(
#     224     starting_agent,
#     225     input,
#     226     context=context,
#     227     max_turns=max_turns,
#     228     hooks=hooks,
#     229     run_config=run_config,
#     230     error_handlers=error_handlers,
#     231     previous_response_id=previous_response_id,
#     232     auto_previous_response_id=auto_previous_response_id,
#     233     conversation_id=conversation_id,
#     234     session=session,
#     235 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\agents\run.py:1059, in AgentRunner.run(self, starting_agent, input, **kwargs)
#    1057         raise
#    1058 else:
# -> 1059     turn_result = await model_task
#    1061 input_guardrail_results.extend(sequential_results)
#    1062 input_guardrail_results.extend(parallel_results)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\futures.py:286, in Future.__await__(self)
#     284 if not self.done():
#     285     self._asyncio_future_blocking = True
# --> 286     yield self  # This tells Task to wait for completion.
#     287 if not self.done():
#     288     raise RuntimeError("await wasn't used with future")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\tasks.py:375, in Task.__wakeup(self, future)
#     373 def __wakeup(self, future):
#     374     try:
# --> 375         future.result()
#     376     except BaseException as exc:
#     377         # This may also be a cancellation.
#     378         self.__step(exc)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\tasks.py:304, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     300 try:
#     301     if exc is None:
#     302         # We use the `send` method directly, because coroutines
#     303         # don't have `__iter__` and `__next__` methods.
# --> 304         result = coro.send(None)
#     305     else:
#     306         result = coro.throw(exc)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\agents\run_internal\run_loop.py:1504, in run_single_turn(agent, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, server_conversation_tracker, session, session_items_to_rewind, reasoning_item_id_policy)
#    1501 if isinstance(input, list):
#    1502     input = normalize_input_items_for_api(input)
# -> 1504 new_response = await get_new_response(
#    1505     agent,
#    1506     system_prompt,
#    1507     input,
#    1508     output_schema,
#    1509     all_tools,
#    1510     handoffs,
#    1511     hooks,
#    1512     context_wrapper,
#    1513     run_config,
#    1514     tool_use_tracker,
#    1515     server_conversation_tracker,
#    1516     prompt_config,
#    1517     session=session,
#    1518     session_items_to_rewind=session_items_to_rewind,
#    1519 )
#    1521 return await get_single_step_result_from_response(
#    1522     agent=agent,
#    1523     original_input=original_input,
#    (...)   1532     tool_use_tracker=tool_use_tracker,
#    1533 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\agents\run_internal\run_loop.py:1599, in get_new_response(agent, system_prompt, input, output_schema, all_tools, handoffs, hooks, context_wrapper, run_config, tool_use_tracker, server_conversation_tracker, prompt_config, session, session_items_to_rewind)
#    1596     logger.debug("No conversation_id available for request")
#    1598 try:
# -> 1599     new_response = await model.get_response(
#    1600         system_instructions=filtered.instructions,
#    1601         input=filtered.input,
#    1602         model_settings=model_settings,
#    1603         tools=all_tools,
#    1604         output_schema=output_schema,
#    1605         handoffs=handoffs,
#    1606         tracing=get_model_tracing_impl(
#    1607             run_config.tracing_disabled, run_config.trace_include_sensitive_data
#    1608         ),
#    1609         previous_response_id=previous_response_id,
#    1610         conversation_id=conversation_id,
#    1611         prompt=prompt_config,
#    1612     )
#    1613 except Exception as exc:
#    1614     from openai import BadRequestError
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\agents\models\openai_chatcompletions.py:108, in OpenAIChatCompletionsModel.get_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, tracing, previous_response_id, conversation_id, prompt)
#      90 async def get_response(
#      91     self,
#      92     system_instructions: str | None,
#    (...)    101     prompt: ResponsePromptParam | None = None,
#     102 ) -> ModelResponse:
#     103     with generation_span(
#     104         model=str(self.model),
#     105         model_config=model_settings.to_json_dict() | {"base_url": str(self._client.base_url)},
#     106         disabled=tracing.is_disabled(),
#     107     ) as span_generation:
# --> 108         response = await self._fetch_response(
#     109             system_instructions,
#     110             input,
#     111             model_settings,
#     112             tools,
#     113             output_schema,
#     114             handoffs,
#     115             span_generation,
#     116             tracing,
#     117             stream=False,
#     118             prompt=prompt,
#     119         )
#     121         message: ChatCompletionMessage | None = None
#     122         first_choice: Choice | None = None
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\agents\models\openai_chatcompletions.py:373, in OpenAIChatCompletionsModel._fetch_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, span, tracing, stream, prompt)
#     367 stream_options = ChatCmplHelpers.get_stream_options_param(
#     368     self._get_client(), model_settings, stream=stream
#     369 )
#     371 stream_param: Literal[True] | Omit = True if stream else omit
# --> 373 ret = await self._get_client().chat.completions.create(
#     374     model=self.model,
#     375     messages=converted_messages,
#     376     tools=tools_param,
#     377     temperature=self._non_null_or_omit(model_settings.temperature),
#     378     top_p=self._non_null_or_omit(model_settings.top_p),
#     379     frequency_penalty=self._non_null_or_omit(model_settings.frequency_penalty),
#     380     presence_penalty=self._non_null_or_omit(model_settings.presence_penalty),
#     381     max_tokens=self._non_null_or_omit(model_settings.max_tokens),
#     382     tool_choice=tool_choice,
#     383     response_format=response_format,
#     384     parallel_tool_calls=parallel_tool_calls,
#     385     stream=cast(Any, stream_param),
#     386     stream_options=self._non_null_or_omit(stream_options),
#     387     store=self._non_null_or_omit(store),
#     388     reasoning_effort=self._non_null_or_omit(reasoning_effort),
#     389     verbosity=self._non_null_or_omit(model_settings.verbosity),
#     390     top_logprobs=self._non_null_or_omit(model_settings.top_logprobs),
#     391     prompt_cache_retention=self._non_null_or_omit(model_settings.prompt_cache_retention),
#     392     extra_headers=self._merge_headers(model_settings),
#     393     extra_query=model_settings.extra_query,
#     394     extra_body=model_settings.extra_body,
#     395     metadata=self._non_null_or_omit(model_settings.metadata),
#     396     **(model_settings.extra_args or {}),
#     397 )
#     399 if isinstance(ret, ChatCompletion):
#     400     return ret
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\resources\chat\completions\completions.py:2714, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    2667 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    2668 async def create(
#    2669     self,
#    (...)   2711     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    2712 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    2713     validate_response_format(response_format)
# -> 2714     return await self._post(
#    2715         "/chat/completions",
#    2716         body=await async_maybe_transform(
#    2717             {
#    2718                 "messages": messages,
#    2719                 "model": model,
#    2720                 "audio": audio,
#    2721                 "frequency_penalty": frequency_penalty,
#    2722                 "function_call": function_call,
#    2723                 "functions": functions,
#    2724                 "logit_bias": logit_bias,
#    2725                 "logprobs": logprobs,
#    2726                 "max_completion_tokens": max_completion_tokens,
#    2727                 "max_tokens": max_tokens,
#    2728                 "metadata": metadata,
#    2729                 "modalities": modalities,
#    2730                 "n": n,
#    2731                 "parallel_tool_calls": parallel_tool_calls,
#    2732                 "prediction": prediction,
#    2733                 "presence_penalty": presence_penalty,
#    2734                 "prompt_cache_key": prompt_cache_key,
#    2735                 "prompt_cache_retention": prompt_cache_retention,
#    2736                 "reasoning_effort": reasoning_effort,
#    2737                 "response_format": response_format,
#    2738                 "safety_identifier": safety_identifier,
#    2739                 "seed": seed,
#    2740                 "service_tier": service_tier,
#    2741                 "stop": stop,
#    2742                 "store": store,
#    2743                 "stream": stream,
#    2744                 "stream_options": stream_options,
#    2745                 "temperature": temperature,
#    2746                 "tool_choice": tool_choice,
#    2747                 "tools": tools,
#    2748                 "top_logprobs": top_logprobs,
#    2749                 "top_p": top_p,
#    2750                 "user": user,
#    2751                 "verbosity": verbosity,
#    2752                 "web_search_options": web_search_options,
#    2753             },
#    2754             completion_create_params.CompletionCreateParamsStreaming
#    2755             if stream
#    2756             else completion_create_params.CompletionCreateParamsNonStreaming,
#    2757         ),
#    2758         options=make_request_options(
#    2759             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2760         ),
#    2761         cast_to=ChatCompletion,
#    2762         stream=stream or False,
#    2763         stream_cls=AsyncStream[ChatCompletionChunk],
#    2764     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_base_client.py:1884, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1875     warnings.warn(
#    1876         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1877         "Please pass raw bytes via the `content` parameter instead.",
#    1878         DeprecationWarning,
#    1879         stacklevel=2,
#    1880     )
#    1881 opts = FinalRequestOptions.construct(
#    1882     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1883 )
# -> 1884 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_base_client.py:1669, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1666             await err.response.aread()
#    1668         log.debug("Re-raising status error")
# -> 1669         raise self._make_status_error_from_response(err.response) from None
#    1671     break
#    1673 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'code': '1302', 'message': '您的账户已达到速率限制，请您控制请求频率'}, 'request_id': 'da83b8fd-9c04-44ec-ba2c-1203110f34da'}
