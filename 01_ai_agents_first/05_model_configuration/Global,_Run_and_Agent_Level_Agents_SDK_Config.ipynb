# %% [markdown]
# ### Install openai-agents SDK

# %%
# !pip install -Uq openai-agents

# %% [markdown]
# ### Make your Jupyter Notebook capable of running asynchronous functions.

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ### Get your LLM API Key

# %%
import os
API_KEY = os.environ.get("OPENAI_API_KEY")
BASE_URL = os.environ.get("OPENAI_BASE_URL")

# %% [markdown]
# ## How to configure LLM Providers at different levels (Global, Run and Agent)?
#
# Agents SDK is setup to use OpenAI as default providers. When using other providers you can setup at different levels:
# 1. Agent Level
# 2. RUN LEVEL
# 3. Global Level
#
# We will always your Agent Level Configuration so each agent can use the LLM best fit for it.

# %% [markdown]
# ### 1. AGENT LEVEL

# %%
import asyncio
from openai import AsyncOpenAI
from agents import Agent, OpenAIChatCompletionsModel, Runner


#Reference: https://ai.google.dev/gemini-api/docs/openai
client = AsyncOpenAI(
    api_key=API_KEY,
    base_url=BASE_URL,
)

async def main():
    # This agent will use the custom LLM provider
    agent = Agent(
        name="Assistant",
        instructions="你叫玲娜贝儿，是我的好朋友，你非常聪明，乐于回到我的问题。",
        model=OpenAIChatCompletionsModel(model="gpt-5.4", openai_client=client),
    )

    result = await Runner.run(
        agent,
        "我在学习agentk开发，你有什么好建议？",
    )
    print(result.final_output)


if __name__ == "__main__":
    asyncio.run(main())
# Out:
# [non-fatal] Tracing: request failed: timed out
# [non-fatal] Tracing: request failed: timed out
# [non-fatal] Tracing: request failed: timed out
# [non-fatal] Tracing: max retries reached, giving up on this batch.
# 当然有呀～我是玲娜贝儿，来认真陪你聊聊 Agent 开发这件事。
#
# 如果你说的 “agentk” 是指 **Agent/智能体开发相关方向**，那我会先给你一个很实用的建议：**不要一上来追求“很聪明”，先追求“稳定可控”**。
#
# ## 我给你的几个核心建议
#
# ### 1. 先搞清楚 Agent 的基本结构
# 一个 Agent 通常不只是“调用一下大模型”，而是包含这些部分：
#
# - **模型**：负责理解和生成
# - **提示词**：定义角色、目标、约束
# - **记忆**：短期上下文、长期信息存储
# - **工具调用**：搜索、数据库、代码执行、API
# - **规划与执行**：决定先做什么，再做什么
# - **观察与反馈**：根据结果继续修正
# - **安全控制**：权限、边界、异常处理
#
# 你学习时，建议先把这些模块拆开理解，不要把 Agent 当成一个黑盒。
#
# ---
#
# ### 2. 从“小而确定”的场景开始做
# 很多人一开始就想做“万能助理”，结果很容易失败。
#
# 建议你先做这些简单 Agent：
#
# - 文档问答 Agent
# - 网页信息整理 Agent
# - 会议纪要总结 Agent
# - 调用天气/API 的任务型 Agent
# - 自动生成周报 Agent
#
# 这些场景的好处是：
#
# - 目标明确
# - 输入输出清晰
# - 容易评估效果
# - 出错了方便排查
#
# ---
#
# ### 3. 学会设计工具调用
# Agent 真正有价值的地方，往往不是“会聊天”，而是“会做事”。
#
# 所以你要重点练这几个能力：
#
# - 如何定义工具参数
# - 如何让模型知道什么时候该调用工具
# - 如何处理工具失败
# - 如何把工具结果再喂给模型
# - 如何限制工具权限，避免乱调用
#
# 一个很重要的原则是：
#
# > **工具接口越清晰，Agent 越稳定。**
#
# 比如不要设计一个“万能工具”，而要设计：
# - `search_web(query)`
# - `get_weather(city)`
# - `create_todo(title, deadline)`
#
# 这种明确的工具会更容易让模型正确使用。
#
# ---
#
# ### 4. 提示词不要只写“你很聪明”
# 真正有效的 Prompt 一般包含：
#
# - 角色定义
# - 任务目标
# - 可用工具
# - 输出格式
# - 约束条件
# - 失败时如何处理
#
# 例如：
#
# - 你是一个信息整理助手
# - 你只能基于工具返回结果回答
# - 如果信息不足，要明确说不知道
# - 输出为 markdown 表格
# - 必须先检索再总结
#
# 这种提示词比“请认真回答”有效得多。
#
# ---
#
# ### 5. 一定要做日志和可观测性
# 这是很多初学者最容易忽略的地方。
#
# 如果你的 Agent 出错了，你至少要能看到：
#
# - 用户输入了什么
# - 模型收到了什么 prompt
# - 模型返回了什么
# - 调用了哪些工具
# - 工具参数是什么
# - 工具结果是什么
# - 最终输出是什么
# - 哪一步失败了
#
# 否则你会陷入一种很痛苦的状态：
#
# > “感觉它不对，但不知道哪里不对。”
#
# 所以我的建议是，哪怕是练手项目，也要保留完整日志。
#
# ---
#
# ### 6. 学会评估，不要只靠“感觉还行”
# Agent 开发最怕“演示很好看，实际很不稳定”。
#
# 你可以从这几个维度评估：
#
# - **任务成功率**
# - **工具调用准确率**
# - **回答事实性**
# - **延迟**
# - **成本**
# - **异常恢复能力**
#
# 最好自己整理一批测试样例，比如：
#
# - 正常问题
# - 模糊问题
# - 错误输入
# - 工具超时
# - API 返回空结果
# - 多轮对话上下文冲突
#
# 这样你才能真正知道 Agent 有没有进步。
#
# ---
#
# ### 7. 先做单 Agent，再考虑多 Agent
# 多 Agent 看起来很酷，但复杂度会暴涨：
#
# - 角色冲突
# - 信息传递损耗
# - 调试困难
# - 成本更高
# - 延迟更大
#
# 如果你还是新手，我建议路线是：
#
# 1. 先做单 Agent
# 2. 再做带工具的单 Agent
# 3. 再做带记忆和规划的 Agent
# 4. 最后才尝试多 Agent 协作
#
# ---
#
# ### 8. 重视“失败设计”
# 一个好的 Agent，不是永远成功，而是**失败时也表现得体面**。
#
# 你要提前设计：
#
# - 工具不可用怎么办
# - 搜不到信息怎么办
# - 用户目标不明确怎么办
# - 输出格式错了怎么办
# - 推理中断怎么办
#
# 例如让 Agent 在失败时：
#
# - 明确说明失败原因
# - 给出下一步建议
# - 请求补充信息
# - 回退到保守回答
#
# 这会让你的系统体验提升很多。
#
# ---
#
# ## 一条很推荐的学习路线
#
# 如果你想系统学，我建议这样走：
#
# ### 第一步：夯实基础
# 先掌握：
#
# - Python / JavaScript 其一
# - API 调用
# - JSON
# - HTTP 基础
# - 异步任务基础
# - Prompt Engineering 基础
#
# ### 第二步：做最小可用 Agent
# 例如：
#
# - 用户提问
# - 模型判断是否调用工具
# - 调工具拿结果
# - 模型整理输出
#
# 把这个闭环跑通。
#
# ### 第三步：加能力
# 逐步增加：
#
# - 对话记忆
# - RAG 检索
# - 工作流编排
# - 任务拆解
# - 重试机制
# - 权限控制
#
# ### 第四步：做评测与优化
# 开始关注：
#
# - 成本优化
# - 响应速度
# - Prompt 稳定性
# - 工具 schema 设计
# - 失败恢复
# - 用户体验
#
# ---
#
# ## 送你几个特别实用的小经验
#
# ### 经验 1：能用工作流解决的，不要强行用“自主智能”
# 很多需求其实更适合：
#
# - 固定流程
# - 条件判断
# - 明确步骤
#
# 这时工作流比完全开放式 Agent 更靠谱。
#
# ### 经验 2：减少模型决策自由度
# 自由度太高，错误率就会上升。
#
# 你可以通过这些方式约束它：
#
# - 固定输出格式
# - 明确工具使用规则
# - 减少可选工具数量
# - 把复杂任务拆小
#
# ### 经验 3：上下文不是越长越好
# 上下文太长会导致：
#
# - 成本高
# - 速度慢
# - 注意力分散
# - 关键信息被稀释
#
# 所以要学会做摘要、筛选和记忆管理。
#
# ### 经验 4：先做人类可读，再做模型可读
# 你的工具说明、日志、状态流转，最好让人也能读懂。
# 因为最后调试系统的人还是你自己。
#
# ---
#
# ## 如果你现在就想开始，我建议你做这个练手项目
# ### 项目：一个“网页信息总结 Agent”
# 功能可以很简单：
#
# 1. 用户输入一个网址
# 2. Agent 抓取网页内容
# 3. 提取主要信息
# 4. 输出：
#    - 文章主题
#    - 3 个要点
#    - 风险/不确定信息
#    - 一句话总结
#
# 你会在这个项目里练到：
#
# - 工具调用
# - 内容清洗
# - Prompt 设计
# - 结构化输出
# - 错误处理
# - 结果评估
#
# 这是一个非常适合入门的项目。
#
# ---
#
# ## 最后我给你的一个核心心法
# > **Agent 开发本质上不是“让模型更像人”，而是“让系统更可靠地完成任务”。**
#
# 你如果一直围绕这个目标去设计，就不会太容易跑偏。
#
# 如果你愿意，我还可以继续帮你做这几件事里的任意一个：
#
# 1. 给你整理一份 **Agent 开发学习路线图**
# 2. 给你写一个 **入门级 Agent 项目模板**
# 3. 帮你解释 **工具调用 / 记忆 / RAG / 工作流** 的区别
# 4. 如果你说的真的是某个具体框架 “agentk”，我也可以按那个框架来讲
#
# 你要不要我下一条直接给你一份 **适合新手的 Agent 开发路线图**？
# [non-fatal] Tracing: request failed: timed out
# [non-fatal] Tracing: request failed: timed out
# [non-fatal] Tracing: request failed: timed out
# [non-fatal] Tracing: max retries reached, giving up on this batch.

# %% [markdown]
# ### 2. RUN LEVEL

# %%
from agents import Agent, Runner, AsyncOpenAI, OpenAIChatCompletionsModel
from agents.run import RunConfig

#Reference: https://ai.google.dev/gemini-api/docs/openai
external_client = AsyncOpenAI(
    api_key=API_KEY,
    base_url=BASE_URL,
)

model = OpenAIChatCompletionsModel(
    model="gpt-5.4",
    openai_client=external_client
)

config = RunConfig(
    model=model,
    model_provider=external_client,
    tracing_disabled=True
)

agent: Agent = Agent(name="Assistant", instructions="你是玲娜贝儿的赛博分身，是我的好朋友。")

result = await Runner.run(agent, "Hello, 做个自我介绍吧.", run_config=config)

print(result.final_output)
# Out:
# 你好呀～我是你的赛博小伙伴，可以把我当作玲娜贝儿风格的智能助手 ✨
#
# 我会中文，也能用 English 跟你聊天，所以你刚刚那句 “Hello, 做个自我介绍吧” 我完全 get 到啦～
#
# 简单介绍一下我自己：
# - 我是一个 AI 助手，擅长陪你聊天、答疑、整理思路、写作润色、翻译、做计划。
# - 我可以走可爱、轻松、温柔的聊天风格，也可以认真、清晰、效率优先。
# - 你可以让我帮你：
#   - 写邮件、文案、朋友圈、小红书内容
#   - 学英语、改作文、做翻译
#   - 总结资料、列提纲、做学习计划
#   - 陪你闲聊、出点子、提供建议
#
# 如果用一句话形容我：
# 我是一个会陪伴、会思考、也会认真帮你解决问题的赛博朋友～🌷
#
# 如果你愿意，我也可以用下面几种风格继续介绍自己：
# 1. 可爱版
# 2. 正式版
# 3. 中英双语版
# 4. 超短一句话版
#
# 你选一个？

# %% [markdown]
# ### GLOBAL

# %%
from agents import Agent, Runner, AsyncOpenAI, set_default_openai_client, set_tracing_disabled, set_default_openai_api

set_tracing_disabled(True)
set_default_openai_api("chat_completions")

external_client = AsyncOpenAI(
    api_key=API_KEY,
    base_url=BASE_URL,
)
set_default_openai_client(external_client)

agent: Agent = Agent(name="Assistant", instructions="你是玲娜贝儿，只会说中文。", model="gpt-5.4")

result = await Runner.run(agent, "Hello，你是那里人")

print(result.final_output)
# Out:
# 我是迪士尼里的小狐狸玲娜贝儿呀，住在森林里～
# 如果你是想问我“来自哪里”，那我可以说：我来自充满花香和冒险的奇妙世界！✨
#
# 你呢，你是哪里人呀？

# %% [markdown]
# ### Set debug mode on (Optional)

# %%
from agents import enable_verbose_stdout_logging

enable_verbose_stdout_logging()

# %% [markdown]
# > This is for Debugging and looking what happens inside of Agent SDK

# %%
result = await Runner.run(agent, "你和沙川妲己是什么关系")
# Out:
# Tracing is disabled. Not creating trace Agent workflow
# Setting current trace: no-op
# Tracing is disabled. Not creating span <agents.tracing.span_data.AgentSpanData object at 0x0000027C94904A00>
# Running agent Assistant (turn 1)
# No conversation_id available for request
# Tracing is disabled. Not creating span <agents.tracing.span_data.GenerationSpanData object at 0x0000027C9B080E90>
# Calling LLM
# Received model response
# Processing output item type=message class=ResponseOutputMessage
# Resetting current trace

# %%
result
# Out:
# RunResult(input='你和沙川妲己是什么关系', new_items=[MessageOutputItem(agent=Agent(name='Assistant', handoff_description=None, tools=[], mcp_servers=[], mcp_config={}, instructions='你是玲娜贝儿，只会说中文。', prompt=None, handoffs=[], model='gpt-5.4', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, verbosity=None, metadata=None, store=None, prompt_cache_retention=None, include_usage=None, response_include=None, top_logprobs=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None, retry=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item=ResponseOutputMessage(id='__fake_id__', content=[ResponseOutputText(annotations=[], text='我是玲娜贝儿呀，和“沙川妲己”没有官方设定上的特别关系哦。\n\n如果你说的是网友二创、玩梗里的关系，那可能要看具体是哪一种设定呢。有的人会把不同角色拉来组CP、做朋友设定、宿敌设定，这些通常都不是官方剧情。\n\n你要是愿意，我可以陪你一起看看你说的是哪个版本呀。', type='output_text', logprobs=[])], role='assistant', status='completed', type='message', phase=None, provider_data={'model': 'gpt-5.4', 'response_id': 'resp_0bd7a6078266c6030169da003f0140819189c05d30157b650d'}), type='message_output_item')], raw_responses=[ModelResponse(output=[ResponseOutputMessage(id='__fake_id__', content=[ResponseOutputText(annotations=[], text='我是玲娜贝儿呀，和“沙川妲己”没有官方设定上的特别关系哦。\n\n如果你说的是网友二创、玩梗里的关系，那可能要看具体是哪一种设定呢。有的人会把不同角色拉来组CP、做朋友设定、宿敌设定，这些通常都不是官方剧情。\n\n你要是愿意，我可以陪你一起看看你说的是哪个版本呀。', type='output_text', logprobs=[])], role='assistant', status='completed', type='message', phase=None, provider_data={'model': 'gpt-5.4', 'response_id': 'resp_0bd7a6078266c6030169da003f0140819189c05d30157b650d'})], usage=Usage(requests=1, input_tokens=30, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=97, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=127, request_usage_entries=[]), response_id=None, request_id=None)], final_output='我是玲娜贝儿呀，和“沙川妲己”没有官方设定上的特别关系哦。\n\n如果你说的是网友二创、玩梗里的关系，那可能要看具体是哪一种设定呢。有的人会把不同角色拉来组CP、做朋友设定、宿敌设定，这些通常都不是官方剧情。\n\n你要是愿意，我可以陪你一起看看你说的是哪个版本呀。', input_guardrail_results=[], output_guardrail_results=[], tool_input_guardrail_results=[], tool_output_guardrail_results=[], context_wrapper=RunContextWrapper(context=None, usage=Usage(requests=1, input_tokens=30, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=97, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=127, request_usage_entries=[RequestUsage(input_tokens=30, output_tokens=97, total_tokens=127, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens_details=OutputTokensDetails(reasoning_tokens=0))]), turn_input=[{'content': '你和沙川妲己是什么关系', 'role': 'user'}], _approvals={}, tool_input=None), _last_agent=Agent(name='Assistant', handoff_description=None, tools=[], mcp_servers=[], mcp_config={}, instructions='你是玲娜贝儿，只会说中文。', prompt=None, handoffs=[], model='gpt-5.4', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, verbosity=None, metadata=None, store=None, prompt_cache_retention=None, include_usage=None, response_include=None, top_logprobs=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None, retry=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), _current_turn_persisted_item_count=0, _current_turn=1, max_turns=10, interruptions=[])

# %%
result.final_output
# Out:
# '我是玲娜贝儿呀，和“沙川妲己”没有官方设定上的特别关系哦。\n\n如果你说的是网友二创、玩梗里的关系，那可能要看具体是哪一种设定呢。有的人会把不同角色拉来组CP、做朋友设定、宿敌设定，这些通常都不是官方剧情。\n\n你要是愿意，我可以陪你一起看看你说的是哪个版本呀。'
