# %% [markdown]
# # 🚀 Exploring the openai-agents Library with Gemini
# This notebook shows how to use the openai-agents library with Gemini API to build conversational agents—covering two execution methods

# %% [markdown]
# # 📦 installation

# %%
# !pip install -Uq openai-agents

# %% [markdown]
# # 📦 Imports

# %%
# 这段代码的作用是解决 Jupyter Notebook/IPython 中的异步事件循环冲突问题，让 asyncio 代码可以在已经运行事件循环的环境中正常执行。
# Jupyter Notebook/IPython 本身已经运行了一个 asyncio 事件循环（用于处理内核通信）
# Python 的 asyncio 默认规则：一个线程只能有一个活跃的事件循环
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# # 📦 Imports

# %%
from agents import Agent, Runner, AsyncOpenAI, OpenAIChatCompletionsModel, set_tracing_disabled

# %% [markdown]
# # 🔐 Step 1: Setup for Api Keys

# %%
import os
gemini_api_key = os.environ.get("GEMINI_API_KEY")

# %% [markdown]
# # 🌐  Step 2: Client Setup for Connecting to **Gemini**

# %%
# Tracing disabled
set_tracing_disabled(disabled=True)

# 1. Which LLM Service?
external_client: AsyncOpenAI = AsyncOpenAI(
    api_key=gemini_api_key,
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
)

# 2. Which LLM Model?
llm_model: OpenAIChatCompletionsModel = OpenAIChatCompletionsModel(
    model="gemini-2.5-flash",
    openai_client=external_client
)

# %% [markdown]
# # 💬  Step 3 Running Agent Synchronously

# %%
math_agent: Agent = Agent(name="MathAgent",
                     instructions="你是一个优秀的数学教学助手.",
                     model=llm_model) # gemini-2.5 as agent brain - chat completions

result: Runner = await Runner.run(math_agent, "学习AI Agents的时候为什么要了解数学?")

print("\nCALLING AGENT\n")
print(result.final_output)
# Out:
# CALLING AGENT
#
# 学习AI Agents时，深入了解数学至关重要。数学不仅是理解AI Agent背后机制的“语言”，更是设计、优化、调试和创新Agent的关键工具。你可以将数学视为AI Agent的“骨架”和“神经系统”。
#
# 以下是学习AI Agents时需要了解数学的几个核心原因：
#
# 1.  **理解和解释模型 (Understanding and Explaining Models):**
#     *   **不只是使用库，更是理解原理：** 很多流行的AI Agent框架（如TensorFlow、PyTorch、OpenAI Gym）提供了高层抽象，但如果你不理解其内部的数学原理，你将无法真正掌握它们为什么有效、在何种情况下会失效。
#     *   **透明度和可解释性：** 了解数学能帮助你剖析模型的决策过程，理解Agent为什么会采取某个行动，这对于开发负责任、可信赖的AI Agent至关重要。
#
# 2.  **核心数学分支及其在AI Agents中的应用：**
#
#     *   **1. 线性代数 (Linear Algebra):**
#         *   **数据表示：** Agent感知到的环境状态、动作、观察值等，常常被表示为向量（vectors）和矩阵（matrices）。例如，图像是像素值的矩阵，文本词嵌入是高维向量。
#         *   **神经网络：** 深度学习是许多高级Agent的核心，而神经网络的运算本质上就是大量的矩阵乘法、向量加法和线性变换。
#         *   **降维与特征提取：** 主成分分析 (PCA) 等技术依赖线性代数来简化复杂数据，帮助Agent关注关键信息。
#
#     *   **2. 概率论与统计学 (Probability and Statistics):**
#         *   **不确定性建模：** 真实世界充满不确定性。Agent需要处理传感器噪声、环境随机性、其他Agent行为的不可预测性。概率论提供了量化和推理不确定性的框架（如贝叶斯网络、马尔可夫决策过程 MDPs）。
#         *   **决策制定：** 强化学习Agent在探索和利用之间做出权衡时，往往基于对未来奖励的概率预测。
#         *   **模型评估：** 统计学提供工具来评估Agent的性能，比较不同Agent策略的效果，进行假设检验等。
#         *   **状态估计：** 粒子滤波、卡尔曼滤波等用于估计Agent在不确定环境中的状态的技术都基于概率论。
#
#     *   **3. 微积分 (Calculus):**
#         *   **优化：** AI Agent的目标通常是最大化某个奖励函数或最小化某个误差函数。微积分（特别是多元微积分）是优化算法（如梯度下降、随机梯度下降 SGD）的基础。
#         *   **学习过程：** 神经网络通过反向传播算法调整权重，这涉及到计算损失函数对每个权重的偏导数。
#         *   **策略梯度：** 在强化学习中，Agent通过策略梯度算法来学习最优策略，这直接依赖于计算梯度。
#
#     *   **4. 离散数学 (Discrete Mathematics):**
#         *   **图论 (Graph Theory):** 路径规划、状态空间搜索、知识表示（语义网络）等都用到图结构。
#         *   **逻辑学 (Logic):** 符号AI Agent、规划、知识表示与推理的基础。
#         *   **算法分析：** 理解Agent算法的计算复杂性（时间复杂度、空间复杂度，如Big O表示法），有助于设计更高效的Agent。
#
#     *   **5. 优化理论 (Optimization Theory):**
#         *   **决策与规划：** 找到最优路径、最佳行动序列、最优策略等，是Agent的核心任务。优化理论提供了解决这类问题的数学框架和算法（线性规划、非线性规划、动态规划等）。
#         *   **模型训练：** 如前所述，训练Agent的过程本身就是一个优化问题。
#
#     *   **6. 信息论 (Information Theory):**
#         *   **信息增益：** 在决策树、主动学习等场景中，Agent可能需要评估不同特征或查询能提供多少有用信息。
#         *   **熵：** 量化不确定性，用于衡量Agent的探索程度或模型复杂度。
#
# 3.  **设计和创新 (Design and Innovation):**
#     *   如果你想开发新的Agent架构、改进现有算法，或者将AI Agent应用于新的领域，就必须拥有坚实的数学基础。这是从“使用者”到“创造者”的关键一步。
#     *   阅读前沿研究论文时，数学公式是其核心内容。缺乏数学背景将难以理解这些论文的贡献和方法。
#
# 4.  **调试和问题解决 (Debugging and Troubleshooting):**
#     *   当你的Agent表现不如预期时，数学可以帮助你诊断问题。例如，梯度消失/爆炸问题、过拟合/欠拟合问题，以及各种统计偏差，都需要数学知识来理解其根本原因并寻找解决方案。
#
# **总结：**
#
# 学习AI Agents，尤其是更高级、更智能的Agents（如强化学习Agent、多Agent系统、基于模型的Agent），数学是你的指南针和地图。它不是让你成为数学家，而是让你能：
#
# *   **看懂：** 理解现有模型的运作原理。
# *   **动手：** 有能力修改、调整、实现复杂算法。
# *   **思考：** 诊断问题，找到解决方案。
# *   **创造：** 提出新的想法和方法。
#
# 因此，建议你同步学习AI Agent的概念与其背后的数学原理，你会发现两者相辅相成，互相促进理解。从基础开始，逐步深入，你将能更好地驾驭AI Agent的复杂世界。

# %%
import rich
rich.print(result)
# Out:
# RunResult(
#     input='学习AI Agents的时候为什么要了解数学?',
#     new_items=[
#         MessageOutputItem(
#             agent=Agent(
#                 name='MathAgent',
#                 handoff_description=None,
#                 tools=[],
#                 mcp_servers=[],
#                 mcp_config={},
#                 instructions='你是一个优秀的数学教学助手.',
#                 prompt=None,
#                 handoffs=[],
#                 model=<agents.models.openai_chatcompletions.OpenAIChatCompletionsModel object at
# 0x000001D13A999590>,
#                 model_settings=ModelSettings(
#                     temperature=None,
#                     top_p=None,
#                     frequency_penalty=None,
#                     presence_penalty=None,
#                     tool_choice=None,
#                     parallel_tool_calls=None,
#                     truncation=None,
#                     max_tokens=None,
#                     reasoning=None,
#                     verbosity=None,
#                     metadata=None,
#                     store=None,
#                     prompt_cache_retention=None,
#                     include_usage=None,
#                     response_include=None,
#                     top_logprobs=None,
#                     extra_query=None,
#                     extra_body=None,
#                     extra_headers=None,
#                     extra_args=None
#                 ),
#                 input_guardrails=[],
#                 output_guardrails=[],
#                 output_type=None,
#                 hooks=None,
#                 tool_use_behavior='run_llm_again',
#                 reset_tool_choice=True
#             ),
#             raw_item=ResponseOutputMessage(
#                 id='__fake_id__',
#                 content=[
#                     ResponseOutputText(
#                         annotations=[],
#                         text='学习AI Agents时，深入了解数学至关重要。数学不仅是理解AI
# Agent背后机制的“语言”，更是设计、优化、调试和创新Agent的关键工具。你可以将数学视为AI
# Agent的“骨架”和“神经系统”。\n\n以下是学习AI Agents时需要了解数学的几个核心原因：\n\n1.  **理解和解释模型
# (Understanding and Explaining Models):**\n    *   **不只是使用库，更是理解原理：** 很多流行的AI
# Agent框架（如TensorFlow、PyTorch、OpenAI
# Gym）提供了高层抽象，但如果你不理解其内部的数学原理，你将无法真正掌握它们为什么有效、在何种情况下会失效。\n    *
# **透明度和可解释性：**
# 了解数学能帮助你剖析模型的决策过程，理解Agent为什么会采取某个行动，这对于开发负责任、可信赖的AI
# Agent至关重要。\n\n2.  **核心数学分支及其在AI Agents中的应用：**\n\n    *   **1. 线性代数 (Linear Algebra):**\n
# *   **数据表示：**
# Agent感知到的环境状态、动作、观察值等，常常被表示为向量（vectors）和矩阵（matrices）。例如，图像是像素值的矩阵，文
# 本词嵌入是高维向量。\n        *   **神经网络：**
# 深度学习是许多高级Agent的核心，而神经网络的运算本质上就是大量的矩阵乘法、向量加法和线性变换。\n        *
# **降维与特征提取：** 主成分分析 (PCA) 等技术依赖线性代数来简化复杂数据，帮助Agent关注关键信息。\n\n    *   **2.
# 概率论与统计学 (Probability and Statistics):**\n        *   **不确定性建模：**
# 真实世界充满不确定性。Agent需要处理传感器噪声、环境随机性、其他Agent行为的不可预测性。概率论提供了量化和推理不确定
# 性的框架（如贝叶斯网络、马尔可夫决策过程 MDPs）。\n        *   **决策制定：**
# 强化学习Agent在探索和利用之间做出权衡时，往往基于对未来奖励的概率预测。\n        *   **模型评估：**
# 统计学提供工具来评估Agent的性能，比较不同Agent策略的效果，进行假设检验等。\n        *   **状态估计：**
# 粒子滤波、卡尔曼滤波等用于估计Agent在不确定环境中的状态的技术都基于概率论。\n\n    *   **3. 微积分 (Calculus):**\n
# *   **优化：** AI
# Agent的目标通常是最大化某个奖励函数或最小化某个误差函数。微积分（特别是多元微积分）是优化算法（如梯度下降、随机梯度
# 下降 SGD）的基础。\n        *   **学习过程：**
# 神经网络通过反向传播算法调整权重，这涉及到计算损失函数对每个权重的偏导数。\n        *   **策略梯度：**
# 在强化学习中，Agent通过策略梯度算法来学习最优策略，这直接依赖于计算梯度。\n\n    *   **4. 离散数学 (Discrete
# Mathematics):**\n        *   **图论 (Graph Theory):**
# 路径规划、状态空间搜索、知识表示（语义网络）等都用到图结构。\n        *   **逻辑学 (Logic):** 符号AI
# Agent、规划、知识表示与推理的基础。\n        *   **算法分析：**
# 理解Agent算法的计算复杂性（时间复杂度、空间复杂度，如Big O表示法），有助于设计更高效的Agent。\n\n    *   **5.
# 优化理论 (Optimization Theory):**\n        *   **决策与规划：**
# 找到最优路径、最佳行动序列、最优策略等，是Agent的核心任务。优化理论提供了解决这类问题的数学框架和算法（线性规划、非
# 线性规划、动态规划等）。\n        *   **模型训练：** 如前所述，训练Agent的过程本身就是一个优化问题。\n\n    *
# **6. 信息论 (Information Theory):**\n        *   **信息增益：**
# 在决策树、主动学习等场景中，Agent可能需要评估不同特征或查询能提供多少有用信息。\n        *   **熵：**
# 量化不确定性，用于衡量Agent的探索程度或模型复杂度。\n\n3.  **设计和创新 (Design and Innovation):**\n    *
# 如果你想开发新的Agent架构、改进现有算法，或者将AI
# Agent应用于新的领域，就必须拥有坚实的数学基础。这是从“使用者”到“创造者”的关键一步。\n    *
# 阅读前沿研究论文时，数学公式是其核心内容。缺乏数学背景将难以理解这些论文的贡献和方法。\n\n4.  **调试和问题解决
# (Debugging and Troubleshooting):**\n    *
# 当你的Agent表现不如预期时，数学可以帮助你诊断问题。例如，梯度消失/爆炸问题、过拟合/欠拟合问题，以及各种统计偏差，都
# 需要数学知识来理解其根本原因并寻找解决方案。\n\n**总结：**\n\n学习AI
# Agents，尤其是更高级、更智能的Agents（如强化学习Agent、多Agent系统、基于模型的Agent），数学是你的指南针和地图。它不
# 是让你成为数学家，而是让你能：\n\n*   **看懂：** 理解现有模型的运作原理。\n*   **动手：**
# 有能力修改、调整、实现复杂算法。\n*   **思考：** 诊断问题，找到解决方案。\n*   **创造：**
# 提出新的想法和方法。\n\n因此，建议你同步学习AI
# Agent的概念与其背后的数学原理，你会发现两者相辅相成，互相促进理解。从基础开始，逐步深入，你将能更好地驾驭AI
# Agent的复杂世界。',
#                         type='output_text',
#                         logprobs=[]
#                     )
#                 ],
#                 role='assistant',
#                 status='completed',
#                 type='message',
#                 phase=None,
#                 provider_data={'model': 'gemini-2.5-flash', 'response_id': 'OYqvaa-6POSi1e8P4qOfqAY'}
#             ),
#             type='message_output_item'
#         )
#     ],
#     raw_responses=[
#         ModelResponse(
#             output=[
#                 ResponseOutputMessage(
#                     id='__fake_id__',
#                     content=[
#                         ResponseOutputText(
#                             annotations=[],
#                             text='学习AI Agents时，深入了解数学至关重要。数学不仅是理解AI
# Agent背后机制的“语言”，更是设计、优化、调试和创新Agent的关键工具。你可以将数学视为AI
# Agent的“骨架”和“神经系统”。\n\n以下是学习AI Agents时需要了解数学的几个核心原因：\n\n1.  **理解和解释模型
# (Understanding and Explaining Models):**\n    *   **不只是使用库，更是理解原理：** 很多流行的AI
# Agent框架（如TensorFlow、PyTorch、OpenAI
# Gym）提供了高层抽象，但如果你不理解其内部的数学原理，你将无法真正掌握它们为什么有效、在何种情况下会失效。\n    *
# **透明度和可解释性：**
# 了解数学能帮助你剖析模型的决策过程，理解Agent为什么会采取某个行动，这对于开发负责任、可信赖的AI
# Agent至关重要。\n\n2.  **核心数学分支及其在AI Agents中的应用：**\n\n    *   **1. 线性代数 (Linear Algebra):**\n
# *   **数据表示：**
# Agent感知到的环境状态、动作、观察值等，常常被表示为向量（vectors）和矩阵（matrices）。例如，图像是像素值的矩阵，文
# 本词嵌入是高维向量。\n        *   **神经网络：**
# 深度学习是许多高级Agent的核心，而神经网络的运算本质上就是大量的矩阵乘法、向量加法和线性变换。\n        *
# **降维与特征提取：** 主成分分析 (PCA) 等技术依赖线性代数来简化复杂数据，帮助Agent关注关键信息。\n\n    *   **2.
# 概率论与统计学 (Probability and Statistics):**\n        *   **不确定性建模：**
# 真实世界充满不确定性。Agent需要处理传感器噪声、环境随机性、其他Agent行为的不可预测性。概率论提供了量化和推理不确定
# 性的框架（如贝叶斯网络、马尔可夫决策过程 MDPs）。\n        *   **决策制定：**
# 强化学习Agent在探索和利用之间做出权衡时，往往基于对未来奖励的概率预测。\n        *   **模型评估：**
# 统计学提供工具来评估Agent的性能，比较不同Agent策略的效果，进行假设检验等。\n        *   **状态估计：**
# 粒子滤波、卡尔曼滤波等用于估计Agent在不确定环境中的状态的技术都基于概率论。\n\n    *   **3. 微积分 (Calculus):**\n
# *   **优化：** AI
# Agent的目标通常是最大化某个奖励函数或最小化某个误差函数。微积分（特别是多元微积分）是优化算法（如梯度下降、随机梯度
# 下降 SGD）的基础。\n        *   **学习过程：**
# 神经网络通过反向传播算法调整权重，这涉及到计算损失函数对每个权重的偏导数。\n        *   **策略梯度：**
# 在强化学习中，Agent通过策略梯度算法来学习最优策略，这直接依赖于计算梯度。\n\n    *   **4. 离散数学 (Discrete
# Mathematics):**\n        *   **图论 (Graph Theory):**
# 路径规划、状态空间搜索、知识表示（语义网络）等都用到图结构。\n        *   **逻辑学 (Logic):** 符号AI
# Agent、规划、知识表示与推理的基础。\n        *   **算法分析：**
# 理解Agent算法的计算复杂性（时间复杂度、空间复杂度，如Big O表示法），有助于设计更高效的Agent。\n\n    *   **5.
# 优化理论 (Optimization Theory):**\n        *   **决策与规划：**
# 找到最优路径、最佳行动序列、最优策略等，是Agent的核心任务。优化理论提供了解决这类问题的数学框架和算法（线性规划、非
# 线性规划、动态规划等）。\n        *   **模型训练：** 如前所述，训练Agent的过程本身就是一个优化问题。\n\n    *
# **6. 信息论 (Information Theory):**\n        *   **信息增益：**
# 在决策树、主动学习等场景中，Agent可能需要评估不同特征或查询能提供多少有用信息。\n        *   **熵：**
# 量化不确定性，用于衡量Agent的探索程度或模型复杂度。\n\n3.  **设计和创新 (Design and Innovation):**\n    *
# 如果你想开发新的Agent架构、改进现有算法，或者将AI
# Agent应用于新的领域，就必须拥有坚实的数学基础。这是从“使用者”到“创造者”的关键一步。\n    *
# 阅读前沿研究论文时，数学公式是其核心内容。缺乏数学背景将难以理解这些论文的贡献和方法。\n\n4.  **调试和问题解决
# (Debugging and Troubleshooting):**\n    *
# 当你的Agent表现不如预期时，数学可以帮助你诊断问题。例如，梯度消失/爆炸问题、过拟合/欠拟合问题，以及各种统计偏差，都
# 需要数学知识来理解其根本原因并寻找解决方案。\n\n**总结：**\n\n学习AI
# Agents，尤其是更高级、更智能的Agents（如强化学习Agent、多Agent系统、基于模型的Agent），数学是你的指南针和地图。它不
# 是让你成为数学家，而是让你能：\n\n*   **看懂：** 理解现有模型的运作原理。\n*   **动手：**
# 有能力修改、调整、实现复杂算法。\n*   **思考：** 诊断问题，找到解决方案。\n*   **创造：**
# 提出新的想法和方法。\n\n因此，建议你同步学习AI
# Agent的概念与其背后的数学原理，你会发现两者相辅相成，互相促进理解。从基础开始，逐步深入，你将能更好地驾驭AI
# Agent的复杂世界。',
#                             type='output_text',
#                             logprobs=[]
#                         )
#                     ],
#                     role='assistant',
#                     status='completed',
#                     type='message',
#                     phase=None,
#                     provider_data={'model': 'gemini-2.5-flash', 'response_id': 'OYqvaa-6POSi1e8P4qOfqAY'}
#                 )
#             ],
#             usage=Usage(
#                 requests=1,
#                 input_tokens=17,
#                 input_tokens_details=InputTokensDetails(cached_tokens=0),
#                 output_tokens=1233,
#                 output_tokens_details=OutputTokensDetails(reasoning_tokens=0),
#                 total_tokens=2511,
#                 request_usage_entries=[]
#             ),
#             response_id=None,
#             request_id=None
#         )
#     ],
#     final_output='学习AI Agents时，深入了解数学至关重要。数学不仅是理解AI
# Agent背后机制的“语言”，更是设计、优化、调试和创新Agent的关键工具。你可以将数学视为AI
# Agent的“骨架”和“神经系统”。\n\n以下是学习AI Agents时需要了解数学的几个核心原因：\n\n1.  **理解和解释模型
# (Understanding and Explaining Models):**\n    *   **不只是使用库，更是理解原理：** 很多流行的AI
# Agent框架（如TensorFlow、PyTorch、OpenAI
# Gym）提供了高层抽象，但如果你不理解其内部的数学原理，你将无法真正掌握它们为什么有效、在何种情况下会失效。\n    *
# **透明度和可解释性：**
# 了解数学能帮助你剖析模型的决策过程，理解Agent为什么会采取某个行动，这对于开发负责任、可信赖的AI
# Agent至关重要。\n\n2.  **核心数学分支及其在AI Agents中的应用：**\n\n    *   **1. 线性代数 (Linear Algebra):**\n
# *   **数据表示：**
# Agent感知到的环境状态、动作、观察值等，常常被表示为向量（vectors）和矩阵（matrices）。例如，图像是像素值的矩阵，文
# 本词嵌入是高维向量。\n        *   **神经网络：**
# 深度学习是许多高级Agent的核心，而神经网络的运算本质上就是大量的矩阵乘法、向量加法和线性变换。\n        *
# **降维与特征提取：** 主成分分析 (PCA) 等技术依赖线性代数来简化复杂数据，帮助Agent关注关键信息。\n\n    *   **2.
# 概率论与统计学 (Probability and Statistics):**\n        *   **不确定性建模：**
# 真实世界充满不确定性。Agent需要处理传感器噪声、环境随机性、其他Agent行为的不可预测性。概率论提供了量化和推理不确定
# 性的框架（如贝叶斯网络、马尔可夫决策过程 MDPs）。\n        *   **决策制定：**
# 强化学习Agent在探索和利用之间做出权衡时，往往基于对未来奖励的概率预测。\n        *   **模型评估：**
# 统计学提供工具来评估Agent的性能，比较不同Agent策略的效果，进行假设检验等。\n        *   **状态估计：**
# 粒子滤波、卡尔曼滤波等用于估计Agent在不确定环境中的状态的技术都基于概率论。\n\n    *   **3. 微积分 (Calculus):**\n
# *   **优化：** AI
# Agent的目标通常是最大化某个奖励函数或最小化某个误差函数。微积分（特别是多元微积分）是优化算法（如梯度下降、随机梯度
# 下降 SGD）的基础。\n        *   **学习过程：**
# 神经网络通过反向传播算法调整权重，这涉及到计算损失函数对每个权重的偏导数。\n        *   **策略梯度：**
# 在强化学习中，Agent通过策略梯度算法来学习最优策略，这直接依赖于计算梯度。\n\n    *   **4. 离散数学 (Discrete
# Mathematics):**\n        *   **图论 (Graph Theory):**
# 路径规划、状态空间搜索、知识表示（语义网络）等都用到图结构。\n        *   **逻辑学 (Logic):** 符号AI
# Agent、规划、知识表示与推理的基础。\n        *   **算法分析：**
# 理解Agent算法的计算复杂性（时间复杂度、空间复杂度，如Big O表示法），有助于设计更高效的Agent。\n\n    *   **5.
# 优化理论 (Optimization Theory):**\n        *   **决策与规划：**
# 找到最优路径、最佳行动序列、最优策略等，是Agent的核心任务。优化理论提供了解决这类问题的数学框架和算法（线性规划、非
# 线性规划、动态规划等）。\n        *   **模型训练：** 如前所述，训练Agent的过程本身就是一个优化问题。\n\n    *
# **6. 信息论 (Information Theory):**\n        *   **信息增益：**
# 在决策树、主动学习等场景中，Agent可能需要评估不同特征或查询能提供多少有用信息。\n        *   **熵：**
# 量化不确定性，用于衡量Agent的探索程度或模型复杂度。\n\n3.  **设计和创新 (Design and Innovation):**\n    *
# 如果你想开发新的Agent架构、改进现有算法，或者将AI
# Agent应用于新的领域，就必须拥有坚实的数学基础。这是从“使用者”到“创造者”的关键一步。\n    *
# 阅读前沿研究论文时，数学公式是其核心内容。缺乏数学背景将难以理解这些论文的贡献和方法。\n\n4.  **调试和问题解决
# (Debugging and Troubleshooting):**\n    *
# 当你的Agent表现不如预期时，数学可以帮助你诊断问题。例如，梯度消失/爆炸问题、过拟合/欠拟合问题，以及各种统计偏差，都
# 需要数学知识来理解其根本原因并寻找解决方案。\n\n**总结：**\n\n学习AI
# Agents，尤其是更高级、更智能的Agents（如强化学习Agent、多Agent系统、基于模型的Agent），数学是你的指南针和地图。它不
# 是让你成为数学家，而是让你能：\n\n*   **看懂：** 理解现有模型的运作原理。\n*   **动手：**
# 有能力修改、调整、实现复杂算法。\n*   **思考：** 诊断问题，找到解决方案。\n*   **创造：**
# 提出新的想法和方法。\n\n因此，建议你同步学习AI
# Agent的概念与其背后的数学原理，你会发现两者相辅相成，互相促进理解。从基础开始，逐步深入，你将能更好地驾驭AI
# Agent的复杂世界。',
#     input_guardrail_results=[],
#     output_guardrail_results=[],
#     tool_input_guardrail_results=[],
#     tool_output_guardrail_results=[],
#     context_wrapper=RunContextWrapper(
#         context=None,
#         usage=Usage(
#             requests=1,
#             input_tokens=17,
#             input_tokens_details=InputTokensDetails(cached_tokens=0),
#             output_tokens=1233,
#             output_tokens_details=OutputTokensDetails(reasoning_tokens=0),
#             total_tokens=2511,
#             request_usage_entries=[
#                 RequestUsage(
#                     input_tokens=17,
#                     output_tokens=1233,
#                     total_tokens=2511,
#                     input_tokens_details=InputTokensDetails(cached_tokens=0),
#                     output_tokens_details=OutputTokensDetails(reasoning_tokens=0)
#                 )
#             ]
#         ),
#         turn_input=[{'content': '学习AI Agents的时候为什么要了解数学?', 'role': 'user'}],
#         _approvals={},
#         tool_input=None
#     ),
#     _last_agent=Agent(
#         name='MathAgent',
#         handoff_description=None,
#         tools=[],
#         mcp_servers=[],
#         mcp_config={},
#         instructions='你是一个优秀的数学教学助手.',
#         prompt=None,
#         handoffs=[],
#         model=<agents.models.openai_chatcompletions.OpenAIChatCompletionsModel object at 0x000001D13A999590>,
#         model_settings=ModelSettings(
#             temperature=None,
#             top_p=None,
#             frequency_penalty=None,
#             presence_penalty=None,
#             tool_choice=None,
#             parallel_tool_calls=None,
#             truncation=None,
#             max_tokens=None,
#             reasoning=None,
#             verbosity=None,
#             metadata=None,
#             store=None,
#             prompt_cache_retention=None,
#             include_usage=None,
#             response_include=None,
#             top_logprobs=None,
#             extra_query=None,
#             extra_body=None,
#             extra_headers=None,
#             extra_args=None
#         ),
#         input_guardrails=[],
#         output_guardrails=[],
#         output_type=None,
#         hooks=None,
#         tool_use_behavior='run_llm_again',
#         reset_tool_choice=True
#     ),
#     _current_turn_persisted_item_count=0,
#     _current_turn=1,
#     max_turns=10,
#     interruptions=[]
# )

# %% [markdown]
# # 💬 Step 3: Running Agent Asynchronously

# %%
import asyncio

async def main():

    result: Runner = await Runner.run(math_agent, "对编程中的递归技巧进行介绍。")

    print(result.final_output)


asyncio.run(main())
# Out:
# 编程中的递归（Recursion）是一种强大的技巧，它允许一个函数调用自身来解决问题。当一个问题可以被分解成与原问题相似但规模更小的子问题时，递归就成为一种非常自然和优雅的解决方案。
#
# ### 1. 什么是递归？
#
# 简单来说，**递归就是函数在执行过程中调用自身**。
#
# **核心思想：**
# 将一个大问题分解为若干个与原问题相同，但规模更小的子问题，直到子问题足够小，可以直接解决（这个可以直接解决的子问题就是“基本情况”或“基线条件”）。
#
# **一个形象的比喻：**
# *   **俄罗斯套娃：** 大套娃里面有小套娃，小套娃里面还有更小的套娃，直到最小的那个套娃不能再打开。
# *   **镜子对着镜子：** 你会看到无限多个你，每个都比前一个“小”一点。
#
# ### 2. 递归的两个关键要素
#
# 任何一个成功的递归函数都必须包含两个基本要素：
#
# 1.  **基本情况（Base Case / 停止条件）：**
#     *   这是递归的“出口”。
#     *   当满足某个条件时，函数不再调用自身，而是直接返回一个确定的结果。
#     *   **重要性：** 没有基本情况，递归将无限进行下去，导致“栈溢出”（Stack Overflow Error）。
#
# 2.  **递归步骤（Recursive Step / 递推关系）：**
#     *   函数调用自身，处理规模更小的子问题。
#     *   每次调用都必须让问题向基本情况的方向“缩小”。
#
# ### 3. 经典示例：计算阶乘 (Factorial)
#
# 阶乘的定义是数学上递归的一个完美例子：
# *   $n! = n \times (n-1)!$
# *   $1! = 1$
# *   $0! = 1$
#
# 让我们用Python来实现：
#
# ```python
# def factorial(n):
#     # 1. 基本情况 (Base Case):
#     # 当 n 为 0 或 1 时，直接返回 1
#     if n == 0 or n == 1:
#         return 1
#     # 2. 递归步骤 (Recursive Step):
#     # n! = n * (n-1)!
#     else:
#         return n * factorial(n - 1)
#
# # 测试
# print(f"5! = {factorial(5)}")   # 输出: 5! = 120
# print(f"0! = {factorial(0)}")   # 输出: 0! = 1
# # print(factorial(-1)) # 这会进入无限递归，导致栈溢出，因为没有负数的基线条件
# ```
#
# **执行流程追踪 (以 `factorial(3)` 为例):**
#
# 1.  `factorial(3)` 被调用。`n` 不是 `0` 或 `1`。
# 2.  返回 `3 * factorial(2)`。
#     *   `factorial(2)` 被调用。`n` 不是 `0` 或 `1`。
#     *   返回 `2 * factorial(1)`。
#         *   `factorial(1)` 被调用。`n` 是 `1` (基本情况)。
#         *   返回 `1`。
#     *   `factorial(2)` 接收到 `1`，计算 `2 * 1 = 2`。
#     *   返回 `2`。
# 3.  `factorial(3)` 接收到 `2`，计算 `3 * 2 = 6`。
# 4.  返回 `6`。
#
# 这个过程就像把问题一层层地剥开，直到遇到最小的可以直接解决的问题，然后再把结果一层层地组装回去。
#
# ### 4. 递归的优缺点
#
# **优点：**
#
# 1.  **代码简洁优雅：** 对于某些问题（如树的遍历、某些数学定义），递归的解决方案非常自然，代码量少且易于理解。
# 2.  **符合问题结构：** 对于本身具有递归结构的问题（如分形、树形结构、图的深度优先搜索），使用递归可以更直观地表达算法。
# 3.  **分而治之：** 许多高效算法（如快速排序、归并排序）都采用“分而治之”的思想，天然适合用递归实现。
#
# **缺点：**
#
# 1.  **性能开销：** 每次函数调用都会伴随着创建新的栈帧（保存局部变量、返回地址等信息），这会增加时间和空间的开销。对于大规模问题，可能比迭代慢。
# 2.  **栈溢出：** 如果递归深度过大（例如，没有正确设置基本情况，或问题本身需要极深的递归），会导致调用栈溢出，程序崩溃。
# 3.  **理解和调试难度：** 有时候，递归的执行流程可能不如迭代直观，调试起来也相对困难。
# 4.  **重复计算：** 某些简单的递归实现（如朴素的斐波那契数列）会进行大量的重复计算，导致效率极低。可以通过“记忆化搜索”（memoization）或动态规划来优化。
#
# ### 5. 什么时候使用递归？
#
# *   **问题天然具有递归结构：**
#     *   树和图的遍历（深度优先搜索 DFS）。
#     *   分治算法（归并排序、快速排序、二分查找）。
#     *   数学上的递归定义（阶乘、斐波那契数列）。
#     *   迷宫求解、八皇后问题、汉诺塔等回溯算法。
# *   **代码简洁性优先于极致性能：** 在递归深度不深且性能要求不苛刻的情况下，递归可以使代码更清晰。
#
# ### 6. 递归 vs. 迭代
#
# *   **递归：** 函数调用自身，通过调用栈（call stack）来管理中间状态。
# *   **迭代：** 使用循环（`for`、`while`），通过循环变量来管理中间状态。
#
# 理论上，任何递归问题都可以转换为迭代问题，反之亦然。选择哪种方式取决于问题的性质、代码的可读性以及性能要求。
#
# **示例：斐波那契数列**
#
# *   **递归版 (简洁但低效，有重复计算)**
#     ```python
#     def fib_recursive(n):
#         if n <= 1:
#             return n
#         else:
#             return fib_recursive(n-1) + fib_recursive(n-2)
#     ```
# *   **迭代版 (高效)**
#     ```python
#     def fib_iterative(n):
#         if n <= 1:
#             return n
#         a, b = 0, 1
#         for _ in range(n - 1):
#             a, b = b, a + b
#         return b
#     ```
#
# ### 7. 尾递归优化 (Tail Recursion Optimization - TCO)
#
# *   **什么是尾递归？** 如果一个递归调用是函数体中最后执行的操作，并且它的返回值直接就是整个函数的返回值，那么这就是尾递归。
# *   **优化：** 某些编译器或解释器（如Scheme、Scala等，但Python**不支持**）可以识别尾递归，并将其优化为迭代形式，从而避免栈溢出和函数调用的开销。这使得尾递归在这些语言中可以拥有迭代的性能优势。
#
# ```python
# # 尾递归示例 (Python不支持优化，但仍是尾递归的形式)
# def factorial_tail_recursive(n, accumulator=1):
#     if n == 0:
#         return accumulator
#     else:
#         # 递归调用是最后的操作，并且其返回值直接作为函数的返回值
#         return factorial_tail_recursive(n - 1, accumulator * n)
#
# print(f"5! (tail recursive) = {factorial_tail_recursive(5)}")
# ```
#
# ### 总结
#
# 递归是编程中一种优雅且强大的工具，它通过将问题分解为更小的相似子问题来解决复杂任务。理解基本情况、递归步骤以及调用栈的工作原理是掌握递归的关键。虽然它有潜在的性能和栈溢出问题，但在处理某些类型的问题时，递归能够提供更清晰、更自然的解决方案。熟练掌握递归是成为一名优秀程序员的重要一步。

# %% [markdown]
# ## Example 1:
# ### 👨‍🍳🍽️ Recipe Bot

# %%
set_tracing_disabled(disabled=True)

# Client Setup for Connecting to Gemini
external_client:AsyncOpenAI = AsyncOpenAI(
    api_key=gemini_api_key,
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
)

#Initialize model
model:OpenAIChatCompletionsModel = OpenAIChatCompletionsModel(
    model="gemini-2.5-flash",
    openai_client=external_client
)

def main():
  # Create the Recipe Agent
  agent = Agent(
      name="RecipeBot",
      instructions=(
          """You are a helpful recipe assistant. A user will give you a few ingredients
          they have at home, and you will suggest one simple and quick recipe using only those items.
          Keep it short, step-by-step, and easy for beginners to cook."""
      ),
      model=model
  )

  print("\n🍳 What can I cook today?\n")
  ingredients = "eggs, tomatoes, onions, and bread"
  result:Runner = Runner.run_sync(agent, f"I have these at home: {ingredients}. What can I cook?")

  print(result.final_output)

# %%
if __name__ == "__main__":
    main()
# Out:
# 🍳 What can I cook today?
#
# Here's a quick and simple recipe for you:
#
# **Tomato & Onion Scramble on Toast**
#
# This recipe makes 1 serving.
#
# **You'll need:**
# *   2 eggs
# *   1/4 onion
# *   1/2 tomato
# *   2 slices bread
# *   A little cooking oil or butter (optional, but recommended)
# *   Salt and pepper (optional, but recommended)
#
# **Steps:**
#
# 1.  **Prep:** Dice the onion finely. Dice the tomato into small pieces.
# 2.  **Sauté Veggies:** Heat a small pan over medium heat. Add a tiny bit of oil or butter if you have it. Add the diced onion and cook for 2-3 minutes until it starts to soften. Then add the diced tomato and cook for another 1-2 minutes until slightly tender.
# 3.  **Scramble Eggs:** While the veggies cook, crack your eggs into a bowl, add a pinch of salt and pepper (if using), and whisk them lightly with a fork. Pour the whisked eggs into the pan with the cooked vegetables.
# 4.  **Cook & Toast:** Let the eggs set for a few seconds, then gently push and fold them with a spatula until they are cooked to your liking (soft scrambled). At the same time, pop your bread into a toaster or toast it in another pan until golden.
# 5.  **Serve:** Spoon the egg and vegetable mixture onto your toasted bread. Enjoy!
